# %%
import pandas as pd
import re
import numpy as np
import regex

# %%
data = pd.read_csv('../ete3/Plt_sci_publications_geo_species_8.26.csv', low_memory=False)

# %% [markdown]
# # Get dict of names and genders to reduce calls to GenderAPI

# %%
names_dict = data[['First_names_currated', 'inferred_gender']].dropna()

# %%
names_dict['First_names_currated'] = names_dict['First_names_currated'].str.strip()

# %%
# need to drop duplicates here otherwise issues when merging
names_dict = names_dict.drop_duplicates(subset=['First_names_currated'])

# %%
names_dict = names_dict.rename(columns = {'First_names_currated': 'First name'})

# %% [markdown]
# # Fix problems

# %% [markdown]
# Running the line
#
#     re.findall(one_loc_out.iloc[i]['Corresponding_author_last_name']+"+[^;]*", one_loc_out.iloc[i]['Author Full Names'])
#
# in case 2.1 made me realize entries 24144, 25071, and 40426 have an extra semicolon in the corresp. author addresses. Fix these manually here.

# %%
for i in [24144, 25071, 40426]:
    data.at[i,'Corresponding author Addresses'] = data.loc[i]['Corresponding author Addresses'].replace(';', '')

# %% [markdown]
# # Get first names

# %%
# if they have no names we don't care
data = data.dropna(subset='Author Full Names')

# %%
# gather all names of the form Lastname, AB or Lastname, A.B.
all_initials = []

for i in data.index:
    author_list = data.loc[i]['Author Full Names'].split('; ')
    if len([x for x in author_list if not re.findall(', [A-Z]{1,}$',x) and not re.findall(', [A-Z]. [A-Z].$',x) and not re.findall(', [A-Z].$',x)]) == 0:
        all_initials.append(i)

# remove entries with names found above from the dataset
data = data[~data.index.isin(all_initials)]

# %%
# many of these are one author with multiple affiliations

mult_corresp = []

for i in range(len(data['Corresponding author Addresses'])):
    if ';' in data.iloc[i]['Corresponding author Addresses']:
        mult_corresp.append(i)

# %% [markdown]
# ## Case 1: one author, mult affiliations
# Don't need to do anything with these

# %%
one_author = []

for i in mult_corresp:
    test_str = data.iloc[i]['Corresponding author Addresses']
    test_str_list = test_str.split(';')
    stripped_list = [re.findall('[^()]+', i)[0].strip() for i in test_str_list]
    
    if len(set(stripped_list)) == 1:
        one_author.append(i)

# %% [markdown]
# ## Case 2: mult authors

# %%
# get only true mult authors
mult_authors = sorted(list(set(mult_corresp)-set(one_author)))

# %%
mult_authors_df = data.iloc[mult_authors]

# %%
mult_authors_df['Corresponding author Addresses'] = mult_authors_df['Corresponding author Addresses'].str.split(';')
# Out:
# /tmp/ipykernel_447643/4070540700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mult_authors_df['Corresponding author Addresses'] = mult_authors_df['Corresponding author Addresses'].str.split(';')

# %%
mult_authors_df['Corresponding author geocoords'] = mult_authors_df['Corresponding author geocoords'].str.split(';')
# Out:
# /tmp/ipykernel_447643/1495248539.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mult_authors_df['Corresponding author geocoords'] = mult_authors_df['Corresponding author geocoords'].str.split(';')

# %% [markdown]
# ### Subcase 1: Authors all have same location
# In this case, there will be only one location listed under corresp author geocoords

# %%
one_loc_df = mult_authors_df[mult_authors_df['Corresponding author geocoords'].map(len)==1]

# %%
one_loc_df['map_props'] = [1 for i in range(len(one_loc_df))]
# Out:
# /tmp/ipykernel_447643/2763481392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_loc_df['map_props'] = [1 for i in range(len(one_loc_df))]

# %%
one_loc_out = one_loc_df.explode('Corresponding author Addresses')
one_loc_out['map_props'] /= one_loc_out['map_props'].groupby(level=0).transform('count')

# %%
one_loc_out['Corresponding_author_last_name'] = one_loc_out['Corresponding author Addresses'].str.split(', ').str[0]

# %%
one_loc_out['Corresponding_author_last_name'] = one_loc_out['Corresponding_author_last_name'].str.strip()

# %%
# names that just have initials as first names will just have the initials as the first name
one_loc_out["first and last names"]=[re.findall(one_loc_out.iloc[i]['Corresponding_author_last_name']+"+[^;]*", one_loc_out.iloc[i]['Author Full Names']) for i in range(len(one_loc_out))]

# %%
one_loc_out = one_loc_out.reset_index()

# %%
no_authors = []

for i in one_loc_out.index:
    if len(one_loc_out.loc[i]['first and last names']) == 0:
        no_authors.append(i)
        
no_authors_df = one_loc_out.loc[no_authors]

# %%
# need to do the german last name thing
new_last_names = []

for i in list(no_authors_df.index):
    old_last_name = no_authors_df.loc[i]['Corresponding_author_last_name']
    author_full_name = no_authors_df.loc[i]['Author Full Names']
    # if the old last name is one insertion away from something in the author full names, then consider it a match
    new_last_name = regex.findall("("+old_last_name+"){i<=1,d<=1}", author_full_name, overlapped=True)
    # if there are still no matches, ignore for now
    if len(new_last_name) == 0:
        pass    
    else:
        new_last_names.append([i,new_last_name[0]])

# %%
# replace last names in old dataframe with new last names (which contain an extra letter)
for i in range(len(new_last_names)):
    no_authors_df.at[new_last_names[i][0],'Corresponding_author_last_name'] = new_last_names[i][1]

# %%
no_authors_df["first and last names"]=[re.findall(no_authors_df.loc[i]['Corresponding_author_last_name']+"+[^;]*", no_authors_df.loc[i]['Author Full Names']) for i in no_authors_df.index]

# %%
# drop people with no first names at this point
one_loc_out = one_loc_out[one_loc_out["first and last names"].map(len)==1]

# %%
one_loc_out["first and last names"] = [i[0].split(', ') for i in one_loc_out["first and last names"]]

# %%
one_loc_out["First name"] = [i[-1] for i in one_loc_out["first and last names"]]

# %%
one_loc_names = one_loc_out.merge(names_dict, how='left', on='First name')

# %%
one_loc_names["Last name"] = [i[0] for i in one_loc_names["first and last names"]]

# %%
one_loc_na = one_loc_names[one_loc_names['inferred_gender_y'].isna()].drop_duplicates(subset=['First name'])

# %%
one_loc_na['Corresponding_auth_country'] = [i[-1] for i in one_loc_na['Corresponding author locations'].str.split(',')]

# %%
# one_loc_na[['First name','Last name','Corresponding_auth_country']].to_csv('one_location.csv', index=False)

# %%
one_loc_enriched = pd.read_csv('one_location_enriched.csv')

# %%
one_loc_na['inferred_gender'] = list(one_loc_enriched['ga_gender'])

# %%
for i in one_loc_na.index:
    one_loc_names.at[i,'inferred_gender_y'] = one_loc_na.at[i,'inferred_gender']

# %% [markdown]
# ### Subcase 2: All authors have different locations

# %%
diff_loc_df = mult_authors_df[mult_authors_df['Corresponding author geocoords'].map(len)==mult_authors_df['Corresponding author Addresses'].map(len)]

# %%
diff_loc_df['map_props'] = [1 for i in range(len(diff_loc_df))]
# Out:
# /tmp/ipykernel_447643/720741673.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_loc_df['map_props'] = [1 for i in range(len(diff_loc_df))]

# %%
diff_loc_out = diff_loc_df.explode(['Corresponding author Addresses','Corresponding author geocoords'])
diff_loc_out['map_props'] /= diff_loc_out['map_props'].groupby(level=0).transform('count')

# %%
diff_loc_out[0:20]
# Out:
#                                      Author Full Names  \
# 15   Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...
# 15   Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...
# 50   Bernard, Miriam S.; Strittmatter, Martina; Mur...
# 50   Bernard, Miriam S.; Strittmatter, Martina; Mur...
# 132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...
# 132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...
# 204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...
# 204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...
# 249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...
# 249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...
# 251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...
# 251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...
# 541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...
# 541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...
# 662  Sunesen, Ines; Rodriguez, Francisco; Tardivo K...
# 662  Sunesen, Ines; Rodriguez, Francisco; Tardivo K...
# 684  Schoenrock, Kathryn M.; O'Connor, Aisha M.; Ma...
# 684  Schoenrock, Kathryn M.; O'Connor, Aisha M.; Ma...
# 834  Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; N...
# 834  Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; N...
#
#                                          Article Title  \
# 15   CharaciopsisBorzi belongs to the Eustigmatophy...
# 15   CharaciopsisBorzi belongs to the Eustigmatophy...
# 50   Diversity, biogeography and host specificity o...
# 50   Diversity, biogeography and host specificity o...
# 132  Why one species in New Zealand, Pugetia delica...
# 132  Why one species in New Zealand, Pugetia delica...
# 204  Species distinctions among closely related str...
# 204  Species distinctions among closely related str...
# 249  Morphology, ultrastructure and molecular phylo...
# 249  Morphology, ultrastructure and molecular phylo...
# 251  Morpho-molecular diversity and phylogeny of By...
# 251  Morpho-molecular diversity and phylogeny of By...
# 541  Haemolytic activity and reactive oxygen specie...
# 541  Haemolytic activity and reactive oxygen specie...
# 662  Morphological and molecular characterization o...
# 662  Morphological and molecular characterization o...
# 684  Genetic diversity of a marine foundation speci...
# 684  Genetic diversity of a marine foundation speci...
# 834  Effects of nitrogen deficiency on the transcri...
# 834  Effects of nitrogen deficiency on the transcri...
#
#                            Journal  impact factor (2020)  \
# 15   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 15   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 50   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 50   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 132  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 132  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 204  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 204  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 249  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 249  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 251  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 251  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 541  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 541  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 662  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 662  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 684  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 684  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 834  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 834  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
#
#                                        Author Keywords  \
# 15   Characiopsis; Eustigmataceae group; Eustigmato...
# 15   Characiopsis; Eustigmataceae group; Eustigmato...
# 50   5'COI; barcoding; biogeography; endophytes; ho...
# 50   5'COI; barcoding; biogeography; endophytes; ho...
# 132  DNA sequencing; endemic genera; large-subunit ...
# 132  DNA sequencing; endemic genera; large-subunit ...
# 204  Eustigmatophyceae; Eustigmatos; fatty acids; i...
# 204  Eustigmatophyceae; Eustigmatos; fatty acids; i...
# 249  Bysmatrum; cyst; dinoflagellate; eyespot; Peri...
# 249  Bysmatrum; cyst; dinoflagellate; eyespot; Peri...
# 251  benthic dinoflagellate; biogeography; Bysmatru...
# 251  benthic dinoflagellate; biogeography; Bysmatru...
# 541  Dinoflagellate; haemolytic agent; harmful alga...
# 541  Dinoflagellate; haemolytic agent; harmful alga...
# 662  Body scales morphology; cell morphology; Dinop...
# 662  Body scales morphology; cell morphology; Dinop...
# 684  Boreal; climate refugia; dispersal; kelp; micr...
# 684  Boreal; climate refugia; dispersal; kelp; micr...
# 834  Fatty acid; lipid metabolism; molecular regula...
# 834  Fatty acid; lipid metabolism; molecular regula...
#
#                                          Keywords Plus  \
# 15   ALGAL CLASS; PHYLOGENY; ULTRASTRUCTURE; NOMENC...
# 15   ALGAL CLASS; PHYLOGENY; ULTRASTRUCTURE; NOMENC...
# 50   ALGA CAULERPA-TAXIFOLIA; NUCLEAR RIBOSOMAL DNA...
# 50   ALGA CAULERPA-TAXIFOLIA; NUCLEAR RIBOSOMAL DNA...
# 132  SUBUNIT RDNA; GIGARTINACEAE RHODOPHYTA; MAXIMU...
# 132  SUBUNIT RDNA; GIGARTINACEAE RHODOPHYTA; MAXIMU...
# 204  CHAIN ALKYL DIOLS; GREEN-ALGAE; SECONDARY STRU...
# 204  CHAIN ALKYL DIOLS; GREEN-ALGAE; SECONDARY STRU...
# 249  FRESH-WATER DINOFLAGELLATE; RDNA-BASED PHYLOGE...
# 249  FRESH-WATER DINOFLAGELLATE; RDNA-BASED PHYLOGE...
# 251  TIDAL POOL DINOFLAGELLATE; SP. NOV. DINOPHYCEA...
# 251  TIDAL POOL DINOFLAGELLATE; SP. NOV. DINOPHYCEA...
# 541  DINOFLAGELLATE HETEROCAPSA-CIRCULARISQUAMA; RE...
# 541  DINOFLAGELLATE HETEROCAPSA-CIRCULARISQUAMA; RE...
# 662  DINOFLAGELLATE GENUS; HETEROCAPSA; IDENTIFICAT...
# 662  DINOFLAGELLATE GENUS; HETEROCAPSA; IDENTIFICAT...
# 684  KELP POSTELSIA-PALMAEFORMIS; LAMINARIA-HYPERBO...
# 684  KELP POSTELSIA-PALMAEFORMIS; LAMINARIA-HYPERBO...
# 834  LIPID PRODUCTION; LIGHT-INTENSITY; CHLAMYDOMON...
# 834  LIPID PRODUCTION; LIGHT-INTENSITY; CHLAMYDOMON...
#
#                                               Abstract  \
# 15   Characiopsis, established by Borzi in 1895, is...
# 15   Characiopsis, established by Borzi in 1895, is...
# 50   Endophytic filamentous brown algae are known t...
# 50   Endophytic filamentous brown algae are known t...
# 132  Blade-forming red algae occur worldwide and, p...
# 132  Blade-forming red algae occur worldwide and, p...
# 204  There is an increasing interest in the Eustigm...
# 204  There is an increasing interest in the Eustigm...
# 249  The dinoflagellate order Peridiniales encompas...
# 249  The dinoflagellate order Peridiniales encompas...
# 251  The dinoflagellate genus Bysmatrum encompasses...
# 251  The dinoflagellate genus Bysmatrum encompasses...
# 541  Based on haemolytic activity and reactive oxyg...
# 541  Based on haemolytic activity and reactive oxyg...
# 662  A new species of the marine dinophyte genusHet...
# 662  A new species of the marine dinophyte genusHet...
# 684  Worldwide, kelp populations are stressed by wa...
# 684  Worldwide, kelp populations are stressed by wa...
# 834  The soil algal strainParachlorella kessleriTY ...
# 834  The soil algal strainParachlorella kessleriTY ...
#
#                                 Addresses--all authors  \
# 15   [Amaral, Raquel; Santos, Lilia M. A.] Univ Coi...
# 15   [Amaral, Raquel; Santos, Lilia M. A.] Univ Coi...
# 50   [Bernard, Miriam S.; Heesch, Svenja; Leblanc, ...
# 50   [Bernard, Miriam S.; Heesch, Svenja; Leblanc, ...
# 132  [D'Archino, Roberta] Natl Inst Water & Atmosph...
# 132  [D'Archino, Roberta] Natl Inst Water & Atmosph...
# 204  [Kryvenda, Anastasiia; Rybalka, Nataliya; Frie...
# 204  [Kryvenda, Anastasiia; Rybalka, Nataliya; Frie...
# 249  [Luo, Zhaohe; Gu, Li; Gu, Haifeng] Minist Nat ...
# 249  [Luo, Zhaohe; Gu, Li; Gu, Haifeng] Minist Nat ...
# 251  [Luo, Zhaohe; Li, Xintian; Gu, Haifeng] SOA, I...
# 251  [Luo, Zhaohe; Li, Xintian; Gu, Haifeng] SOA, I...
# 541  [Cho, Kichul] Natl Inst Environm Res, Geum Riv...
# 541  [Cho, Kichul] Natl Inst Environm Res, Geum Riv...
# 662  [Sunesen, Ines; Tardivo Kubis, Jonas A.; Aguia...
# 662  [Sunesen, Ines; Tardivo Kubis, Jonas A.; Aguia...
# 684  [Schoenrock, Kathryn M.; O'Connor, Aisha M.] N...
# 684  [Schoenrock, Kathryn M.; O'Connor, Aisha M.] N...
# 834  [Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; ...
# 834  [Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; ...
#
#                                 Nations--all authors  \
# 15                                 Portugal; Czechia
# 15                                 Portugal; Czechia
# 50                     France; Scotland; South Korea
# 50                     France; Scotland; South Korea
# 132               New Zealand; Taiwan; United States
# 132               New Zealand; Taiwan; United States
# 204                                          Germany
# 204                                          Germany
# 249                 China; France; Canada; Indonesia
# 249                 China; France; Canada; Indonesia
# 251  China; Malaysia; France; Belgium; United States
# 251  China; Malaysia; France; Belgium; United States
# 541                               South Korea; Japan
# 541                               South Korea; Japan
# 662                        Argentina; Spain; Germany
# 662                        Argentina; Spain; Germany
# 684         Ireland; United States; France; Portugal
# 684         Ireland; United States; France; Portugal
# 834                             China; United States
# 834                             China; United States
#
#                         Corresponding author Addresses  ...      GDP_2020  \
# 15   Amaral, R (corresponding author), Univ Coimbra...  ...  2.450000e+11
# 15    Elias, M (corresponding author), Univ Ostrava...  ...  2.450000e+11
# 50   Bernard, MS (corresponding author), Sorbonne U...  ...  2.630000e+12
# 50    Peters, AF (corresponding author), Bezhin Ros...  ...  2.630000e+12
# 132  D'Archino, R (corresponding author), Natl Inst...  ...           NaN
# 132   Lin, SM (corresponding author), Natl Taiwan O...  ...           NaN
# 204  Friedl, T (corresponding author), Georg August...  ...  3.850000e+12
# 204   Wolf, M (corresponding author), Univ Wurzburg...  ...  3.850000e+12
# 249  Gu, HF (corresponding author), Minist Nat Reso...  ...  2.630000e+12
# 249   Mertens, KN (corresponding author), IFREMER, ...  ...  2.630000e+12
# 251  Gu, HF (corresponding author), SOA, Inst Ocean...  ...  2.630000e+12
# 251   Mertens, KN (corresponding author), IFREMER, ...  ...  2.630000e+12
# 541  Oda, T (corresponding author), Nagasaki Univ, ...  ...           NaN
# 541   Kim, D (corresponding author), KBSI, Jeju Ctr...  ...           NaN
# 662  Sar, EA (corresponding author), UNLP, FCNyM, D...  ...  3.850000e+12
# 662   Tillmann, U (corresponding author), Helmholz ...  ...  3.850000e+12
# 684  Schoenrock, KM (corresponding author), Natl Un...  ...  2.090000e+13
# 684   Krueger-Hadfield, SA (corresponding author), ...  ...  2.090000e+13
# 834  Xie, SL (corresponding author), Shanxi Univ, S...  ...  2.090000e+13
# 834   Liu, CJ (corresponding author), Brookhaven Na...  ...  2.090000e+13
#
#     _merge                             Locations--all authors  \
# 15    both                Coimbra, Portugal; Ostrava, Czechia
# 15    both                Coimbra, Portugal; Ostrava, Czechia
# 50    both  Roscoff, France; Oban, Argyll, Scotland; Banch...
# 50    both  Roscoff, France; Oban, Argyll, Scotland; Banch...
# 132   both  Wellington, New Zealand; Keelung, Taiwan; Chap...
# 132   both  Wellington, New Zealand; Keelung, Taiwan; Chap...
# 204   both              Gottingen, Germany; Wurzburg, Germany
# 204   both              Gottingen, Germany; Wurzburg, Germany
# 249   both  Xian, Shaanxi, China; Concarneau, France; Vict...
# 249   both  Xian, Shaanxi, China; Concarneau, France; Vict...
# 251   both  Xian, Shaanxi, China; Bachok, Kelantan, Malays...
# 251   both  Xian, Shaanxi, China; Bachok, Kelantan, Malays...
# 541   both  Okcheon Gun, Chungcheongbukd, South Korea; Bun...
# 541   both  Okcheon Gun, Chungcheongbukd, South Korea; Bun...
# 662   both  La Plata, Buenos Aires, Argentina; Subida Radi...
# 662   both  La Plata, Buenos Aires, Argentina; Subida Radi...
# 684   both  Galway, Galway, Ireland; Birmingham, AL, Unite...
# 684   both  Galway, Galway, Ireland; Birmingham, AL, Unite...
# 834   both   Taiyuan, Shanxi, China; Upton, NY, United States
# 834   both   Taiyuan, Shanxi, China; Upton, NY, United States
#
#                                 Geocoords--all authors  \
# 15   (40.20331450000001, -8.4102573); (49.8209226, ...
# 15   (40.20331450000001, -8.4102573); (49.8209226, ...
# 50   (37.41379999999999, 127.5183); (48.703091, -4....
# 50   (37.41379999999999, 127.5183); (48.703091, -4....
# 132  (-41.2923814, 174.77874630000005); (25.1275997...
# 132  (-41.2923814, 174.77874630000005); (25.1275997...
# 204  (49.79130439999999, 9.9533548); (51.5412804000...
# 204  (49.79130439999999, 9.9533548); (51.5412804000...
# 249  (-6.2250138, 106.9004472); (34.2658138, 108.95...
# 249  (-6.2250138, 106.9004472); (34.2658138, 108.95...
# 251  (30.627977, -96.3344068); (34.2658138, 108.954...
# 251  (30.627977, -96.3344068); (34.2658138, 108.954...
# 541  (32.78519960000001, 129.86664059999998); (33.4...
# 541  (32.78519960000001, 129.86664059999998); (33.4...
# 662  (-34.9204948, -57.95356570000001); (42.1861627...
# 662  (-34.9204948, -57.95356570000001); (42.1861627...
# 684  (33.5185892, -86.8103567); (37.0193548, -7.930...
# 684  (33.5185892, -86.8103567); (37.0193548, -7.930...
# 834  (37.8705899, 112.55067); (40.8682379, -72.8791...
# 834  (37.8705899, 112.55067); (40.8682379, -72.8791...
#
#                         Corresponding author locations  \
# 15                 Coimbra, Portugal; Ostrava, Czechia
# 15                 Coimbra, Portugal; Ostrava, Czechia
# 50                     Roscoff, France; Santec, France
# 50                     Roscoff, France; Santec, France
# 132           Wellington, New Zealand; Keelung, Taiwan
# 132           Wellington, New Zealand; Keelung, Taiwan
# 204              Gottingen, Germany; Wurzburg, Germany
# 204              Gottingen, Germany; Wurzburg, Germany
# 249           Xian, Shaanxi, China; Concarneau, France
# 249           Xian, Shaanxi, China; Concarneau, France
# 251           Xian, Shaanxi, China; Concarneau, France
# 251           Xian, Shaanxi, China; Concarneau, France
# 541  Bunkyo Machi, Nagasaki, Japan; Cheju, Jeju Do,...
# 541  Bunkyo Machi, Nagasaki, Japan; Cheju, Jeju Do,...
# 662  La Plata, Buenos Aires, Argentina; Bremerhaven...
# 662  La Plata, Buenos Aires, Argentina; Bremerhaven...
# 684  Galway, Galway, Ireland; Birmingham, AL, Unite...
# 684  Galway, Galway, Ireland; Birmingham, AL, Unite...
# 834   Taiyuan, Shanxi, China; Upton, NY, United States
# 834   Taiyuan, Shanxi, China; Upton, NY, United States
#
#               Corresponding author geocoords Number of authoring countries  \
# 15           (40.20331450000001, -8.4102573)                             2
# 15          (49.8209226, 18.262524300000006)                             2
# 50                   (48.703091, -4.0292009)                             3
# 50                    (48.726199, -3.985325)                             3
# 132        (-41.2923814, 174.77874630000005)                             3
# 132                (25.1275997, 121.7391815)                             3
# 204           (49.79130439999999, 9.9533548)                             1
# 204           (51.54128040000001, 9.9158035)                             1
# 249                (34.2658138, 108.9540936)                             4
# 249           (47.87283400000001, -3.920734)                             4
# 251                (34.2658138, 108.9540936)                             5
# 251           (47.87283400000001, -3.920734)                             5
# 541  (32.78519960000001, 129.86664059999998)                             2
# 541                (33.4996213, 126.5311884)                             2
# 662        (-34.9204948, -57.95356570000001)                             3
# 662                  (53.5395845, 8.5809424)                             3
# 684                (33.5185892, -86.8103567)                             4
# 684          (53.27066800000001, -9.0567905)                             4
# 834                  (37.8705899, 112.55067)                             2
# 834         (40.8682379, -72.87917159999998)                             2
#
#     Number of corresponding countries  \
# 15                                  2
# 15                                  2
# 50                                  1
# 50                                  1
# 132                                 2
# 132                                 2
# 204                                 1
# 204                                 1
# 249                                 2
# 249                                 2
# 251                                 2
# 251                                 2
# 541                                 2
# 541                                 2
# 662                                 2
# 662                                 2
# 684                                 2
# 684                                 2
# 834                                 2
# 834                                 2
#
#                                            unique_NCBI  map_props
# 15   [425071, 2713033, 1431827, 5747, 44429, 271303...        0.5
# 15   [425071, 2713033, 1431827, 5747, 44429, 271303...        0.5
# 50   [90893, 64910, 64922, 64929, 309358, 172714, 6...        0.5
# 50   [90893, 64910, 64922, 64929, 309358, 172714, 6...        0.5
# 132         [217477, 1789642, 1789644, 1789643, 31430]        0.5
# 132         [217477, 1789642, 1789644, 1789643, 31430]        0.5
# 204                               [44427, 5747, 44431]        0.5
# 204                               [44427, 5747, 44431]        0.5
# 249  [54902, 2867, 66803, 991128, 2137288, 1691972,...        0.5
# 249  [54902, 2867, 66803, 991128, 2137288, 1691972,...        0.5
# 251           [2077185, 2077196, 990649, 990648, 2910]        0.5
# 251           [2077185, 2077196, 990649, 990648, 2910]        0.5
# 541  [859642, 90936, 10190, 225107, 139025, 201731,...        0.5
# 541  [859642, 90936, 10190, 225107, 139025, 201731,...        0.5
# 662                                    [2650469, 2918]        0.5
# 662                                    [2650469, 2918]        0.5
# 684                                    [90893, 172714]        0.5
# 684                                    [90893, 172714]        0.5
# 834                            [686709, 1116978, 3074]        0.5
# 834                            [686709, 1116978, 3074]        0.5
#
# [20 rows x 61 columns]

# %%
diff_loc_out['Corresponding_author_last_name'] = diff_loc_out['Corresponding author Addresses'].str.split(', ').str[0]

# %%
diff_loc_out['Corresponding_author_last_name'] = diff_loc_out['Corresponding_author_last_name'].str.strip()

# %%
# names that just have initials as first names will just have the initials as the first name
diff_loc_out["first and last names"]=[re.findall(diff_loc_out.iloc[i]['Corresponding_author_last_name']+"+[^;]*", diff_loc_out.iloc[i]['Author Full Names']) for i in range(len(diff_loc_out))]

# %%
diff_loc_out[0:20]
# Out:
#                                      Author Full Names  \
# 15   Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...
# 15   Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...
# 50   Bernard, Miriam S.; Strittmatter, Martina; Mur...
# 50   Bernard, Miriam S.; Strittmatter, Martina; Mur...
# 132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...
# 132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...
# 204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...
# 204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...
# 249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...
# 249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...
# 251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...
# 251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...
# 541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...
# 541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...
# 662  Sunesen, Ines; Rodriguez, Francisco; Tardivo K...
# 662  Sunesen, Ines; Rodriguez, Francisco; Tardivo K...
# 684  Schoenrock, Kathryn M.; O'Connor, Aisha M.; Ma...
# 684  Schoenrock, Kathryn M.; O'Connor, Aisha M.; Ma...
# 834  Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; N...
# 834  Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; N...
#
#                                          Article Title  \
# 15   CharaciopsisBorzi belongs to the Eustigmatophy...
# 15   CharaciopsisBorzi belongs to the Eustigmatophy...
# 50   Diversity, biogeography and host specificity o...
# 50   Diversity, biogeography and host specificity o...
# 132  Why one species in New Zealand, Pugetia delica...
# 132  Why one species in New Zealand, Pugetia delica...
# 204  Species distinctions among closely related str...
# 204  Species distinctions among closely related str...
# 249  Morphology, ultrastructure and molecular phylo...
# 249  Morphology, ultrastructure and molecular phylo...
# 251  Morpho-molecular diversity and phylogeny of By...
# 251  Morpho-molecular diversity and phylogeny of By...
# 541  Haemolytic activity and reactive oxygen specie...
# 541  Haemolytic activity and reactive oxygen specie...
# 662  Morphological and molecular characterization o...
# 662  Morphological and molecular characterization o...
# 684  Genetic diversity of a marine foundation speci...
# 684  Genetic diversity of a marine foundation speci...
# 834  Effects of nitrogen deficiency on the transcri...
# 834  Effects of nitrogen deficiency on the transcri...
#
#                            Journal  impact factor (2020)  \
# 15   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 15   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 50   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 50   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 132  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 132  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 204  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 204  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 249  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 249  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 251  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 251  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 541  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 541  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 662  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 662  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 684  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 684  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 834  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 834  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
#
#                                        Author Keywords  \
# 15   Characiopsis; Eustigmataceae group; Eustigmato...
# 15   Characiopsis; Eustigmataceae group; Eustigmato...
# 50   5'COI; barcoding; biogeography; endophytes; ho...
# 50   5'COI; barcoding; biogeography; endophytes; ho...
# 132  DNA sequencing; endemic genera; large-subunit ...
# 132  DNA sequencing; endemic genera; large-subunit ...
# 204  Eustigmatophyceae; Eustigmatos; fatty acids; i...
# 204  Eustigmatophyceae; Eustigmatos; fatty acids; i...
# 249  Bysmatrum; cyst; dinoflagellate; eyespot; Peri...
# 249  Bysmatrum; cyst; dinoflagellate; eyespot; Peri...
# 251  benthic dinoflagellate; biogeography; Bysmatru...
# 251  benthic dinoflagellate; biogeography; Bysmatru...
# 541  Dinoflagellate; haemolytic agent; harmful alga...
# 541  Dinoflagellate; haemolytic agent; harmful alga...
# 662  Body scales morphology; cell morphology; Dinop...
# 662  Body scales morphology; cell morphology; Dinop...
# 684  Boreal; climate refugia; dispersal; kelp; micr...
# 684  Boreal; climate refugia; dispersal; kelp; micr...
# 834  Fatty acid; lipid metabolism; molecular regula...
# 834  Fatty acid; lipid metabolism; molecular regula...
#
#                                          Keywords Plus  \
# 15   ALGAL CLASS; PHYLOGENY; ULTRASTRUCTURE; NOMENC...
# 15   ALGAL CLASS; PHYLOGENY; ULTRASTRUCTURE; NOMENC...
# 50   ALGA CAULERPA-TAXIFOLIA; NUCLEAR RIBOSOMAL DNA...
# 50   ALGA CAULERPA-TAXIFOLIA; NUCLEAR RIBOSOMAL DNA...
# 132  SUBUNIT RDNA; GIGARTINACEAE RHODOPHYTA; MAXIMU...
# 132  SUBUNIT RDNA; GIGARTINACEAE RHODOPHYTA; MAXIMU...
# 204  CHAIN ALKYL DIOLS; GREEN-ALGAE; SECONDARY STRU...
# 204  CHAIN ALKYL DIOLS; GREEN-ALGAE; SECONDARY STRU...
# 249  FRESH-WATER DINOFLAGELLATE; RDNA-BASED PHYLOGE...
# 249  FRESH-WATER DINOFLAGELLATE; RDNA-BASED PHYLOGE...
# 251  TIDAL POOL DINOFLAGELLATE; SP. NOV. DINOPHYCEA...
# 251  TIDAL POOL DINOFLAGELLATE; SP. NOV. DINOPHYCEA...
# 541  DINOFLAGELLATE HETEROCAPSA-CIRCULARISQUAMA; RE...
# 541  DINOFLAGELLATE HETEROCAPSA-CIRCULARISQUAMA; RE...
# 662  DINOFLAGELLATE GENUS; HETEROCAPSA; IDENTIFICAT...
# 662  DINOFLAGELLATE GENUS; HETEROCAPSA; IDENTIFICAT...
# 684  KELP POSTELSIA-PALMAEFORMIS; LAMINARIA-HYPERBO...
# 684  KELP POSTELSIA-PALMAEFORMIS; LAMINARIA-HYPERBO...
# 834  LIPID PRODUCTION; LIGHT-INTENSITY; CHLAMYDOMON...
# 834  LIPID PRODUCTION; LIGHT-INTENSITY; CHLAMYDOMON...
#
#                                               Abstract  \
# 15   Characiopsis, established by Borzi in 1895, is...
# 15   Characiopsis, established by Borzi in 1895, is...
# 50   Endophytic filamentous brown algae are known t...
# 50   Endophytic filamentous brown algae are known t...
# 132  Blade-forming red algae occur worldwide and, p...
# 132  Blade-forming red algae occur worldwide and, p...
# 204  There is an increasing interest in the Eustigm...
# 204  There is an increasing interest in the Eustigm...
# 249  The dinoflagellate order Peridiniales encompas...
# 249  The dinoflagellate order Peridiniales encompas...
# 251  The dinoflagellate genus Bysmatrum encompasses...
# 251  The dinoflagellate genus Bysmatrum encompasses...
# 541  Based on haemolytic activity and reactive oxyg...
# 541  Based on haemolytic activity and reactive oxyg...
# 662  A new species of the marine dinophyte genusHet...
# 662  A new species of the marine dinophyte genusHet...
# 684  Worldwide, kelp populations are stressed by wa...
# 684  Worldwide, kelp populations are stressed by wa...
# 834  The soil algal strainParachlorella kessleriTY ...
# 834  The soil algal strainParachlorella kessleriTY ...
#
#                                 Addresses--all authors  \
# 15   [Amaral, Raquel; Santos, Lilia M. A.] Univ Coi...
# 15   [Amaral, Raquel; Santos, Lilia M. A.] Univ Coi...
# 50   [Bernard, Miriam S.; Heesch, Svenja; Leblanc, ...
# 50   [Bernard, Miriam S.; Heesch, Svenja; Leblanc, ...
# 132  [D'Archino, Roberta] Natl Inst Water & Atmosph...
# 132  [D'Archino, Roberta] Natl Inst Water & Atmosph...
# 204  [Kryvenda, Anastasiia; Rybalka, Nataliya; Frie...
# 204  [Kryvenda, Anastasiia; Rybalka, Nataliya; Frie...
# 249  [Luo, Zhaohe; Gu, Li; Gu, Haifeng] Minist Nat ...
# 249  [Luo, Zhaohe; Gu, Li; Gu, Haifeng] Minist Nat ...
# 251  [Luo, Zhaohe; Li, Xintian; Gu, Haifeng] SOA, I...
# 251  [Luo, Zhaohe; Li, Xintian; Gu, Haifeng] SOA, I...
# 541  [Cho, Kichul] Natl Inst Environm Res, Geum Riv...
# 541  [Cho, Kichul] Natl Inst Environm Res, Geum Riv...
# 662  [Sunesen, Ines; Tardivo Kubis, Jonas A.; Aguia...
# 662  [Sunesen, Ines; Tardivo Kubis, Jonas A.; Aguia...
# 684  [Schoenrock, Kathryn M.; O'Connor, Aisha M.] N...
# 684  [Schoenrock, Kathryn M.; O'Connor, Aisha M.] N...
# 834  [Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; ...
# 834  [Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; ...
#
#                                 Nations--all authors  \
# 15                                 Portugal; Czechia
# 15                                 Portugal; Czechia
# 50                     France; Scotland; South Korea
# 50                     France; Scotland; South Korea
# 132               New Zealand; Taiwan; United States
# 132               New Zealand; Taiwan; United States
# 204                                          Germany
# 204                                          Germany
# 249                 China; France; Canada; Indonesia
# 249                 China; France; Canada; Indonesia
# 251  China; Malaysia; France; Belgium; United States
# 251  China; Malaysia; France; Belgium; United States
# 541                               South Korea; Japan
# 541                               South Korea; Japan
# 662                        Argentina; Spain; Germany
# 662                        Argentina; Spain; Germany
# 684         Ireland; United States; France; Portugal
# 684         Ireland; United States; France; Portugal
# 834                             China; United States
# 834                             China; United States
#
#                         Corresponding author Addresses  ...      GDP_2020  \
# 15   Amaral, R (corresponding author), Univ Coimbra...  ...  2.450000e+11
# 15    Elias, M (corresponding author), Univ Ostrava...  ...  2.450000e+11
# 50   Bernard, MS (corresponding author), Sorbonne U...  ...  2.630000e+12
# 50    Peters, AF (corresponding author), Bezhin Ros...  ...  2.630000e+12
# 132  D'Archino, R (corresponding author), Natl Inst...  ...           NaN
# 132   Lin, SM (corresponding author), Natl Taiwan O...  ...           NaN
# 204  Friedl, T (corresponding author), Georg August...  ...  3.850000e+12
# 204   Wolf, M (corresponding author), Univ Wurzburg...  ...  3.850000e+12
# 249  Gu, HF (corresponding author), Minist Nat Reso...  ...  2.630000e+12
# 249   Mertens, KN (corresponding author), IFREMER, ...  ...  2.630000e+12
# 251  Gu, HF (corresponding author), SOA, Inst Ocean...  ...  2.630000e+12
# 251   Mertens, KN (corresponding author), IFREMER, ...  ...  2.630000e+12
# 541  Oda, T (corresponding author), Nagasaki Univ, ...  ...           NaN
# 541   Kim, D (corresponding author), KBSI, Jeju Ctr...  ...           NaN
# 662  Sar, EA (corresponding author), UNLP, FCNyM, D...  ...  3.850000e+12
# 662   Tillmann, U (corresponding author), Helmholz ...  ...  3.850000e+12
# 684  Schoenrock, KM (corresponding author), Natl Un...  ...  2.090000e+13
# 684   Krueger-Hadfield, SA (corresponding author), ...  ...  2.090000e+13
# 834  Xie, SL (corresponding author), Shanxi Univ, S...  ...  2.090000e+13
# 834   Liu, CJ (corresponding author), Brookhaven Na...  ...  2.090000e+13
#
#     _merge                             Locations--all authors  \
# 15    both                Coimbra, Portugal; Ostrava, Czechia
# 15    both                Coimbra, Portugal; Ostrava, Czechia
# 50    both  Roscoff, France; Oban, Argyll, Scotland; Banch...
# 50    both  Roscoff, France; Oban, Argyll, Scotland; Banch...
# 132   both  Wellington, New Zealand; Keelung, Taiwan; Chap...
# 132   both  Wellington, New Zealand; Keelung, Taiwan; Chap...
# 204   both              Gottingen, Germany; Wurzburg, Germany
# 204   both              Gottingen, Germany; Wurzburg, Germany
# 249   both  Xian, Shaanxi, China; Concarneau, France; Vict...
# 249   both  Xian, Shaanxi, China; Concarneau, France; Vict...
# 251   both  Xian, Shaanxi, China; Bachok, Kelantan, Malays...
# 251   both  Xian, Shaanxi, China; Bachok, Kelantan, Malays...
# 541   both  Okcheon Gun, Chungcheongbukd, South Korea; Bun...
# 541   both  Okcheon Gun, Chungcheongbukd, South Korea; Bun...
# 662   both  La Plata, Buenos Aires, Argentina; Subida Radi...
# 662   both  La Plata, Buenos Aires, Argentina; Subida Radi...
# 684   both  Galway, Galway, Ireland; Birmingham, AL, Unite...
# 684   both  Galway, Galway, Ireland; Birmingham, AL, Unite...
# 834   both   Taiyuan, Shanxi, China; Upton, NY, United States
# 834   both   Taiyuan, Shanxi, China; Upton, NY, United States
#
#                                 Geocoords--all authors  \
# 15   (40.20331450000001, -8.4102573); (49.8209226, ...
# 15   (40.20331450000001, -8.4102573); (49.8209226, ...
# 50   (37.41379999999999, 127.5183); (48.703091, -4....
# 50   (37.41379999999999, 127.5183); (48.703091, -4....
# 132  (-41.2923814, 174.77874630000005); (25.1275997...
# 132  (-41.2923814, 174.77874630000005); (25.1275997...
# 204  (49.79130439999999, 9.9533548); (51.5412804000...
# 204  (49.79130439999999, 9.9533548); (51.5412804000...
# 249  (-6.2250138, 106.9004472); (34.2658138, 108.95...
# 249  (-6.2250138, 106.9004472); (34.2658138, 108.95...
# 251  (30.627977, -96.3344068); (34.2658138, 108.954...
# 251  (30.627977, -96.3344068); (34.2658138, 108.954...
# 541  (32.78519960000001, 129.86664059999998); (33.4...
# 541  (32.78519960000001, 129.86664059999998); (33.4...
# 662  (-34.9204948, -57.95356570000001); (42.1861627...
# 662  (-34.9204948, -57.95356570000001); (42.1861627...
# 684  (33.5185892, -86.8103567); (37.0193548, -7.930...
# 684  (33.5185892, -86.8103567); (37.0193548, -7.930...
# 834  (37.8705899, 112.55067); (40.8682379, -72.8791...
# 834  (37.8705899, 112.55067); (40.8682379, -72.8791...
#
#                         Corresponding author locations  \
# 15                 Coimbra, Portugal; Ostrava, Czechia
# 15                 Coimbra, Portugal; Ostrava, Czechia
# 50                     Roscoff, France; Santec, France
# 50                     Roscoff, France; Santec, France
# 132           Wellington, New Zealand; Keelung, Taiwan
# 132           Wellington, New Zealand; Keelung, Taiwan
# 204              Gottingen, Germany; Wurzburg, Germany
# 204              Gottingen, Germany; Wurzburg, Germany
# 249           Xian, Shaanxi, China; Concarneau, France
# 249           Xian, Shaanxi, China; Concarneau, France
# 251           Xian, Shaanxi, China; Concarneau, France
# 251           Xian, Shaanxi, China; Concarneau, France
# 541  Bunkyo Machi, Nagasaki, Japan; Cheju, Jeju Do,...
# 541  Bunkyo Machi, Nagasaki, Japan; Cheju, Jeju Do,...
# 662  La Plata, Buenos Aires, Argentina; Bremerhaven...
# 662  La Plata, Buenos Aires, Argentina; Bremerhaven...
# 684  Galway, Galway, Ireland; Birmingham, AL, Unite...
# 684  Galway, Galway, Ireland; Birmingham, AL, Unite...
# 834   Taiyuan, Shanxi, China; Upton, NY, United States
# 834   Taiyuan, Shanxi, China; Upton, NY, United States
#
#               Corresponding author geocoords Number of authoring countries  \
# 15           (40.20331450000001, -8.4102573)                             2
# 15          (49.8209226, 18.262524300000006)                             2
# 50                   (48.703091, -4.0292009)                             3
# 50                    (48.726199, -3.985325)                             3
# 132        (-41.2923814, 174.77874630000005)                             3
# 132                (25.1275997, 121.7391815)                             3
# 204           (49.79130439999999, 9.9533548)                             1
# 204           (51.54128040000001, 9.9158035)                             1
# 249                (34.2658138, 108.9540936)                             4
# 249           (47.87283400000001, -3.920734)                             4
# 251                (34.2658138, 108.9540936)                             5
# 251           (47.87283400000001, -3.920734)                             5
# 541  (32.78519960000001, 129.86664059999998)                             2
# 541                (33.4996213, 126.5311884)                             2
# 662        (-34.9204948, -57.95356570000001)                             3
# 662                  (53.5395845, 8.5809424)                             3
# 684                (33.5185892, -86.8103567)                             4
# 684          (53.27066800000001, -9.0567905)                             4
# 834                  (37.8705899, 112.55067)                             2
# 834         (40.8682379, -72.87917159999998)                             2
#
#     Number of corresponding countries  \
# 15                                  2
# 15                                  2
# 50                                  1
# 50                                  1
# 132                                 2
# 132                                 2
# 204                                 1
# 204                                 1
# 249                                 2
# 249                                 2
# 251                                 2
# 251                                 2
# 541                                 2
# 541                                 2
# 662                                 2
# 662                                 2
# 684                                 2
# 684                                 2
# 834                                 2
# 834                                 2
#
#                                            unique_NCBI  map_props
# 15   [425071, 2713033, 1431827, 5747, 44429, 271303...        0.5
# 15   [425071, 2713033, 1431827, 5747, 44429, 271303...        0.5
# 50   [90893, 64910, 64922, 64929, 309358, 172714, 6...        0.5
# 50   [90893, 64910, 64922, 64929, 309358, 172714, 6...        0.5
# 132         [217477, 1789642, 1789644, 1789643, 31430]        0.5
# 132         [217477, 1789642, 1789644, 1789643, 31430]        0.5
# 204                               [44427, 5747, 44431]        0.5
# 204                               [44427, 5747, 44431]        0.5
# 249  [54902, 2867, 66803, 991128, 2137288, 1691972,...        0.5
# 249  [54902, 2867, 66803, 991128, 2137288, 1691972,...        0.5
# 251           [2077185, 2077196, 990649, 990648, 2910]        0.5
# 251           [2077185, 2077196, 990649, 990648, 2910]        0.5
# 541  [859642, 90936, 10190, 225107, 139025, 201731,...        0.5
# 541  [859642, 90936, 10190, 225107, 139025, 201731,...        0.5
# 662                                    [2650469, 2918]        0.5
# 662                                    [2650469, 2918]        0.5
# 684                                    [90893, 172714]        0.5
# 684                                    [90893, 172714]        0.5
# 834                            [686709, 1116978, 3074]        0.5
# 834                            [686709, 1116978, 3074]        0.5
#
# [20 rows x 61 columns]

# %%
diff_loc_out = diff_loc_out.reset_index()

# %%
diff_loc_out[0:20]
# Out:
#     index                                  Author Full Names  \
# 0      15  Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...
# 1      15  Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...
# 2      50  Bernard, Miriam S.; Strittmatter, Martina; Mur...
# 3      50  Bernard, Miriam S.; Strittmatter, Martina; Mur...
# 4     132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...
# 5     132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...
# 6     204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...
# 7     204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...
# 8     249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...
# 9     249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...
# 10    251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...
# 11    251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...
# 12    541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...
# 13    541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...
# 14    662  Sunesen, Ines; Rodriguez, Francisco; Tardivo K...
# 15    662  Sunesen, Ines; Rodriguez, Francisco; Tardivo K...
# 16    684  Schoenrock, Kathryn M.; O'Connor, Aisha M.; Ma...
# 17    684  Schoenrock, Kathryn M.; O'Connor, Aisha M.; Ma...
# 18    834  Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; N...
# 19    834  Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; N...
#
#                                         Article Title  \
# 0   CharaciopsisBorzi belongs to the Eustigmatophy...
# 1   CharaciopsisBorzi belongs to the Eustigmatophy...
# 2   Diversity, biogeography and host specificity o...
# 3   Diversity, biogeography and host specificity o...
# 4   Why one species in New Zealand, Pugetia delica...
# 5   Why one species in New Zealand, Pugetia delica...
# 6   Species distinctions among closely related str...
# 7   Species distinctions among closely related str...
# 8   Morphology, ultrastructure and molecular phylo...
# 9   Morphology, ultrastructure and molecular phylo...
# 10  Morpho-molecular diversity and phylogeny of By...
# 11  Morpho-molecular diversity and phylogeny of By...
# 12  Haemolytic activity and reactive oxygen specie...
# 13  Haemolytic activity and reactive oxygen specie...
# 14  Morphological and molecular characterization o...
# 15  Morphological and molecular characterization o...
# 16  Genetic diversity of a marine foundation speci...
# 17  Genetic diversity of a marine foundation speci...
# 18  Effects of nitrogen deficiency on the transcri...
# 19  Effects of nitrogen deficiency on the transcri...
#
#                           Journal  impact factor (2020)  \
# 0   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 1   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 2   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 3   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 4   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 5   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 6   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 7   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 8   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 9   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 10  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 11  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 12  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 13  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 14  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 15  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 16  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 17  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 18  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 19  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
#
#                                       Author Keywords  \
# 0   Characiopsis; Eustigmataceae group; Eustigmato...
# 1   Characiopsis; Eustigmataceae group; Eustigmato...
# 2   5'COI; barcoding; biogeography; endophytes; ho...
# 3   5'COI; barcoding; biogeography; endophytes; ho...
# 4   DNA sequencing; endemic genera; large-subunit ...
# 5   DNA sequencing; endemic genera; large-subunit ...
# 6   Eustigmatophyceae; Eustigmatos; fatty acids; i...
# 7   Eustigmatophyceae; Eustigmatos; fatty acids; i...
# 8   Bysmatrum; cyst; dinoflagellate; eyespot; Peri...
# 9   Bysmatrum; cyst; dinoflagellate; eyespot; Peri...
# 10  benthic dinoflagellate; biogeography; Bysmatru...
# 11  benthic dinoflagellate; biogeography; Bysmatru...
# 12  Dinoflagellate; haemolytic agent; harmful alga...
# 13  Dinoflagellate; haemolytic agent; harmful alga...
# 14  Body scales morphology; cell morphology; Dinop...
# 15  Body scales morphology; cell morphology; Dinop...
# 16  Boreal; climate refugia; dispersal; kelp; micr...
# 17  Boreal; climate refugia; dispersal; kelp; micr...
# 18  Fatty acid; lipid metabolism; molecular regula...
# 19  Fatty acid; lipid metabolism; molecular regula...
#
#                                         Keywords Plus  \
# 0   ALGAL CLASS; PHYLOGENY; ULTRASTRUCTURE; NOMENC...
# 1   ALGAL CLASS; PHYLOGENY; ULTRASTRUCTURE; NOMENC...
# 2   ALGA CAULERPA-TAXIFOLIA; NUCLEAR RIBOSOMAL DNA...
# 3   ALGA CAULERPA-TAXIFOLIA; NUCLEAR RIBOSOMAL DNA...
# 4   SUBUNIT RDNA; GIGARTINACEAE RHODOPHYTA; MAXIMU...
# 5   SUBUNIT RDNA; GIGARTINACEAE RHODOPHYTA; MAXIMU...
# 6   CHAIN ALKYL DIOLS; GREEN-ALGAE; SECONDARY STRU...
# 7   CHAIN ALKYL DIOLS; GREEN-ALGAE; SECONDARY STRU...
# 8   FRESH-WATER DINOFLAGELLATE; RDNA-BASED PHYLOGE...
# 9   FRESH-WATER DINOFLAGELLATE; RDNA-BASED PHYLOGE...
# 10  TIDAL POOL DINOFLAGELLATE; SP. NOV. DINOPHYCEA...
# 11  TIDAL POOL DINOFLAGELLATE; SP. NOV. DINOPHYCEA...
# 12  DINOFLAGELLATE HETEROCAPSA-CIRCULARISQUAMA; RE...
# 13  DINOFLAGELLATE HETEROCAPSA-CIRCULARISQUAMA; RE...
# 14  DINOFLAGELLATE GENUS; HETEROCAPSA; IDENTIFICAT...
# 15  DINOFLAGELLATE GENUS; HETEROCAPSA; IDENTIFICAT...
# 16  KELP POSTELSIA-PALMAEFORMIS; LAMINARIA-HYPERBO...
# 17  KELP POSTELSIA-PALMAEFORMIS; LAMINARIA-HYPERBO...
# 18  LIPID PRODUCTION; LIGHT-INTENSITY; CHLAMYDOMON...
# 19  LIPID PRODUCTION; LIGHT-INTENSITY; CHLAMYDOMON...
#
#                                              Abstract  \
# 0   Characiopsis, established by Borzi in 1895, is...
# 1   Characiopsis, established by Borzi in 1895, is...
# 2   Endophytic filamentous brown algae are known t...
# 3   Endophytic filamentous brown algae are known t...
# 4   Blade-forming red algae occur worldwide and, p...
# 5   Blade-forming red algae occur worldwide and, p...
# 6   There is an increasing interest in the Eustigm...
# 7   There is an increasing interest in the Eustigm...
# 8   The dinoflagellate order Peridiniales encompas...
# 9   The dinoflagellate order Peridiniales encompas...
# 10  The dinoflagellate genus Bysmatrum encompasses...
# 11  The dinoflagellate genus Bysmatrum encompasses...
# 12  Based on haemolytic activity and reactive oxyg...
# 13  Based on haemolytic activity and reactive oxyg...
# 14  A new species of the marine dinophyte genusHet...
# 15  A new species of the marine dinophyte genusHet...
# 16  Worldwide, kelp populations are stressed by wa...
# 17  Worldwide, kelp populations are stressed by wa...
# 18  The soil algal strainParachlorella kessleriTY ...
# 19  The soil algal strainParachlorella kessleriTY ...
#
#                                Addresses--all authors  \
# 0   [Amaral, Raquel; Santos, Lilia M. A.] Univ Coi...
# 1   [Amaral, Raquel; Santos, Lilia M. A.] Univ Coi...
# 2   [Bernard, Miriam S.; Heesch, Svenja; Leblanc, ...
# 3   [Bernard, Miriam S.; Heesch, Svenja; Leblanc, ...
# 4   [D'Archino, Roberta] Natl Inst Water & Atmosph...
# 5   [D'Archino, Roberta] Natl Inst Water & Atmosph...
# 6   [Kryvenda, Anastasiia; Rybalka, Nataliya; Frie...
# 7   [Kryvenda, Anastasiia; Rybalka, Nataliya; Frie...
# 8   [Luo, Zhaohe; Gu, Li; Gu, Haifeng] Minist Nat ...
# 9   [Luo, Zhaohe; Gu, Li; Gu, Haifeng] Minist Nat ...
# 10  [Luo, Zhaohe; Li, Xintian; Gu, Haifeng] SOA, I...
# 11  [Luo, Zhaohe; Li, Xintian; Gu, Haifeng] SOA, I...
# 12  [Cho, Kichul] Natl Inst Environm Res, Geum Riv...
# 13  [Cho, Kichul] Natl Inst Environm Res, Geum Riv...
# 14  [Sunesen, Ines; Tardivo Kubis, Jonas A.; Aguia...
# 15  [Sunesen, Ines; Tardivo Kubis, Jonas A.; Aguia...
# 16  [Schoenrock, Kathryn M.; O'Connor, Aisha M.] N...
# 17  [Schoenrock, Kathryn M.; O'Connor, Aisha M.] N...
# 18  [Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; ...
# 19  [Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; ...
#
#                                Nations--all authors  ...      GDP_2020 _merge  \
# 0                                 Portugal; Czechia  ...  2.450000e+11   both
# 1                                 Portugal; Czechia  ...  2.450000e+11   both
# 2                     France; Scotland; South Korea  ...  2.630000e+12   both
# 3                     France; Scotland; South Korea  ...  2.630000e+12   both
# 4                New Zealand; Taiwan; United States  ...           NaN   both
# 5                New Zealand; Taiwan; United States  ...           NaN   both
# 6                                           Germany  ...  3.850000e+12   both
# 7                                           Germany  ...  3.850000e+12   both
# 8                  China; France; Canada; Indonesia  ...  2.630000e+12   both
# 9                  China; France; Canada; Indonesia  ...  2.630000e+12   both
# 10  China; Malaysia; France; Belgium; United States  ...  2.630000e+12   both
# 11  China; Malaysia; France; Belgium; United States  ...  2.630000e+12   both
# 12                               South Korea; Japan  ...           NaN   both
# 13                               South Korea; Japan  ...           NaN   both
Galway, Galway, Ireland; Birmingham, AL, Unite...
# 18   Taiyuan, Shanxi, China; Upton, NY, United States
# 19   Taiyuan, Shanxi, China; Upton, NY, United States
#
#              Corresponding author geocoords Number of authoring countries  \
# 0           (40.20331450000001, -8.4102573)                             2
# 1          (49.8209226, 18.262524300000006)                             2
# 2                   (48.703091, -4.0292009)                             3
# 3                    (48.726199, -3.985325)                             3
# 4         (-41.2923814, 174.77874630000005)                             3
# 5                 (25.1275997, 121.7391815)                             3
# 6            (49.79130439999999, 9.9533548)                             1
# 7            (51.54128040000001, 9.9158035)                             1
# 8                 (34.2658138, 108.9540936)                             4
# 9            (47.87283400000001, -3.920734)                             4
# 10                (34.2658138, 108.9540936)                             5
# 11           (47.87283400000001, -3.920734)                             5
# 12  (32.78519960000001, 129.86664059999998)                             2
# 13                (33.4996213, 126.5311884)                             2
# 14        (-34.9204948, -57.95356570000001)                             3
# 15                  (53.5395845, 8.5809424)                             3
# 16                (33.5185892, -86.8103567)                             4
# 17          (53.27066800000001, -9.0567905)                             4
# 18                  (37.8705899, 112.55067)                             2
# 19         (40.8682379, -72.87917159999998)                             2
#
#    Number of corresponding countries  \
# 0                                  2
# 1                                  2
# 2                                  1
# 3                                  1
# 4                                  2
# 5                                  2
# 6                                  1
# 7                                  1
# 8                                  2
# 9                                  2
# 10                                 2
# 11                                 2
# 12                                 2
# 13                                 2
# 14                                 2
# 15                                 2
# 16                                 2
# 17                                 2
# 18                                 2
# 19                                 2
#
#                                           unique_NCBI map_props
# 0   [425071, 2713033, 1431827, 5747, 44429, 271303...       0.5
# 1   [425071, 2713033, 1431827, 5747, 44429, 271303...       0.5
# 2   [90893, 64910, 64922, 64929, 309358, 172714, 6...       0.5
# 3   [90893, 64910, 64922, 64929, 309358, 172714, 6...       0.5
# 4          [217477, 1789642, 1789644, 1789643, 31430]       0.5
# 5          [217477, 1789642, 1789644, 1789643, 31430]       0.5
# 6                                [44427, 5747, 44431]       0.5
# 7                                [44427, 5747, 44431]       0.5
# 8   [54902, 2867, 66803, 991128, 2137288, 1691972,...       0.5
# 9   [54902, 2867, 66803, 991128, 2137288, 1691972,...       0.5
# 10           [2077185, 2077196, 990649, 990648, 2910]       0.5
# 11           [2077185, 2077196, 990649, 990648, 2910]       0.5
# 12  [859642, 90936, 10190, 225107, 139025, 201731,...       0.5
# 13  [859642, 90936, 10190, 225107, 139025, 201731,...       0.5
# 14                                    [2650469, 2918]       0.5
# 15                                    [2650469, 2918]       0.5
# 16                                    [90893, 172714]       0.5
# 17                                    [90893, 172714]       0.5
# 18                            [686709, 1116978, 3074]       0.5
# 19                            [686709, 1116978, 3074]       0.5
#
# [20 rows x 62 columns]

# %%
# find entries that have no corresponding author name extracted
no_authors_diff = []

for i in diff_loc_out.index:
    if len(diff_loc_out.loc[i]['first and last names']) == 0:
        no_authors_diff.append(i)
        
no_authors_diff_df = diff_loc_out.loc[no_authors_diff]

# %%
no_authors_diff_df
# Out:
#        index                                  Author Full Names  \
# 252    22643  Zhou, Zhipeng; Li, Guoliang; Tan, Siyu; Li, Do...
# 328    26421  Ramireddy, Eswarayya; Galuszka, Petr; Schmuell...
# 345    27321  Zhang, Wenying; Wang, Jun; Xu, Le; Wang, Aiai;...
# 909   cyanobacteria; Hapalosiphon; hapalindoles; imm...
# 912   humulone; protopine; Humulus lupulus; Eschscho...
# 935   Zobellia galactanivorans; antibiotics; dialkyl...
# 936   Zobellia galactanivorans; antibiotics; dialkyl...
# 997   Chlorophyll breakdown; Chlorophyll turnover; P...
# 1255  6-Benzyladenine; Chemical thinning; Chlorophyl...
# 1434  benzoxazinoids; endophytes; flavonoids; fungus...
# 1674  Hemiberlesia lataniae; Musa acuminata x balbis...
# 1843  Araceae; Monsteroideae; Chloroplast genome; Po...
# 2389  Marasmius oreades agglutinin; Arabidopsis; Het...
# 2489  Oncidium; Piriformospora indica; Erwinia chrys...
# 2915  Zanthoxylum armatum; Tambulin; Vasorelaxation;...
# 3068  SARS-CoV-2; COVID-19; Pneumonia; Shufeng Jiedu...
# 3238  disease resistance; plant immunity; ribosome; ...
# 3291  hemp; yellow stem; retting; fiber quality; IFB...
# 3293  gas exchange; downy mildew; Vitis vinifera; ph...
# 3760  biodiversity; ecology; pollen; bumble bee; ITS...
# 3972  wheat; split N application; baking quality; pr...
# 4116  biochemical photosynthesis model; chlorophyll ...
# 4166  albostrians; chloroplast biogenesis; chloropla...
# 4169  Arabidopsis thaliana; CCT domain; chloroplast ...
# 4546                                                NaN
# 4667  wheat; single nucleotide polymorphisms; geneti...
# 4767  filaments; cytoophidia; cytidine triphosphate ...
# 5186  glycine decarboxylase; mitochondria; mitochond...
# 5260  abiotic stress; Chenopodium quinoa; EBC; epide...
# 5798                                                NaN
# 5821                                                NaN
# 5826                                                NaN
# 5892                                                NaN
# 6398  land use; soil organic carbon; caatinga; semi-...
# 6514  climate change; environmental stress; low dose...
# 6730  maize germplasm; molecular markers; genetic re...
# 6838  Maize; Abiotic stress; Low phosphorus toleranc...
# 7336  Asphodelus tenuifolius; Vascular smooth muscle...
# 8006                                                NaN
# 8615  Meliaceae; Lansium domesticum; Tetranortriterp...
# 8851  Acid phosphatase; Organic acids; Insoluble pho...
# 8858  minirhizotron images; Time-series; Manual anno...
# 9375  Cnesmone javanica; anxiolytic; antidepressant;...
# 9428  chlorophyll fluorescence; antioxidant enzymes;...
# 9470  ethnobotany; traditional medicine; use value; ...
# 9494  elements; nutrition; medicinal plants; traditi...
# 9551  cereal leaf beetle; wheat; heading time; Ppd-D...
# 9756                PS-MS; bioactive compounds; Poaceae
# 9873  maize; abiotic stress; germination; seedlings;...
#
#                                           Keywords Plus  \
# 252   ENCODES; GENE; SIZE; ARCHITECTURE; WEIGHT; CEL...
# 328                       ARABIDOPSIS; BIOFORTIFICATION
# 345   SALT TOLERANCE; GROWTH; ARABIDOPSIS; EXPRESSIO...
# 574   BROAD-LEAVED FOREST; SPATIAL AUTOCORRELATION; ...
# 909   AMBIGUINE ISONITRILES; NATURAL-PRODUCTS; INDOL...
# 912   ESCHSCHOLZIA-CALIFORNICA; METABOLISM; TRANSPOR...
# 935                  BIOSYNTHESIS; SUBSTANCES; STEMPHOL
# 936                  BIOSYNTHESIS; SUBSTANCES; STEMPHOL
# 997   LEAF SENESCENCE; STAY-GREEN; PROTEIN-DEGRADATI...
# 9551  CHRYSOMELIDAE; PHOTOPERIOD; COLEOPTERA; SELECTION
# 9756  CE HUBB.; ANTIOXIDANT; FLAVONOIDS; PHYLOGENY; ...
# 9873  CLIMATE-CHANGE; STRESS; CULTIVARS; TRITICALE; ...
#
#                                                Abstract  \
# 252   Grain yield and its component traits are essen...
# 328   Zinc (Zn) is an essential element in human nut...
# 345   As an endophytic fungus of Sebacinales, Pirifo...
# 574   Biotic interactions play an important role in ...
# 909   Novel immunomodulating agents are currently so...
# 912   The placental passage of humulone and protopin...
# 935   Zobellia galactanivorans has been reported as ...
# 936   Zobellia galactanivorans has been reported as ...
# 997   Chlorophyll (Chl) breakdown is a diagnostic vi...
# 1255  To achieve a high quantity of premium class fr...
# 1434  The interactions of crops with root-colonizing...
# 1674  The interaction of two Sternorrhyncha species,...
# 1843  Main conclusion This study provides broad insi...
# 2389  Background Plant-parasitic nematodes and herbi...
# 2489  Background: Erwinia chrysanthemi (Ec) is a des...
# 2915  Background: Zanthoxylum armatum DC (Z. armatum...
# 3068  Background: Shufeng Jiedu capsules (SFJDC), a ...
# 3238  Ribosomes play an integral part in plant growt...
# 3291  Hemp is a sustainable and environmental friend...
# 3293  Downy mildew caused by Plasmopara viticola is ...
# 3760  Bumble bees are important crop pollinators and...
# 3972  Baking quality of wheat flour is determined by...
# 4116  Combining information of plant physiological p...
# 4166  Gene pairs resulting from whole genome duplica...
# 4169  The Arabidopsis gene Chloroplast Import Appara...
# 4546  Brassica oleracea forms a diverse and economic...
# 4667  The continuous increase in global population p...
# 4767  Cytidine triphosphate (CTP) is essential for D...
# 5186  Thioredoxins (TRXs) are important proteins inv...
# 5260  Chenopodium quinoa (quinoa) is considered a su...
# 5798  Mitochondrial complex I is the main site for e...
# 5821  Glucosylation modulates the biological activit...
# 5826  Chloroplasts fuel plant development and growth...
# 5892  Stomata are microscopic pores found on the sur...
# 6398  Total organic carbon (TOC) and total nitrogen ...
# 6514  Echinochloa colona (junglerice) is a problemat...
# 6730  The genetic diversity among an international c...
# 6838  Maize (Zea mays L.) is an important crop world...
# 7336  Ethnopharmacological relevance: Asphodelus ten...
# 8006  The noursamycins A-F are chlorinated cyclic he...
# 8615  Seven tetranortriterpenoids including two new ...
# 8851  AimsThe root endophytic fungus Piriformospora ...
# 8858  Background and aims Minirhizotrons are commonl...
# 9375  This study assessed the anxiolytic and antidep...
# 9428  The main objective of this research was to exa...
# 9470  The study was performed in the mid hills of th...
# 9494  The aim of this study was to determine the ele...
# 9551  Wheat production can be severely damaged by en...
# 9756  The characterization of plant compounds with p...
# 9873  Maize is known to be susceptible to drought st...
#
#                                  Addresses--all authors  \
# 252   [Zhou, Zhipeng; Li, Guoliang; Tan, Siyu; Li, D...
# 328   [Ramireddy, Eswarayya; Schmuelling, Thomas] Fr...
# 345   [Zhang, Wenying; Wang, Jun; Xu, Le; Wang, Aiai...
# 574   [Zulqarnain; van Melis, J.] Univ Campinas UNIC...
# 909   [Chilczuk, Tomasz; Breinlinger, Steffen; Niede...
# 912   [Spiess, Deborah; Duong, Elisa; Simoes-Wuest, ...
# 9551  [Wuerschum, Tobias] Univ Hohenheim, Seed Sci &...
# 9756  [do Nascimento, Cezar D.; Paula, Ana C. C. F. ...
# 9873  [Badr, Abdelfattah] Helwan Univ, Fac Sci, Bot ...
#
#                                    Nations--all authors  ...      GDP_2020  \
# 252                                      China; Germany  ...  3.850000e+12
# 328                             Germany; India; Czechia  ...  2.670000e+12
# 345                                      China; Germany  ...  3.850000e+12
# 574                                    Brazil; Pakistan  ...  3.000000e+11
# 909                                             Germany  ...  3.850000e+12
# 912                                         Switzerland  ...  7.520000e+11
# 935                                             Germany  ...  3.850000e+12
# 936                                             Germany  ...  3.850000e+12
# 997                                Austria; Switzerland  ...  7.520000e+11
# 1255                                            Germany  ...  3.850000e+12
# 1434                               Germany; New Zealand  ...  2.120000e+11
# 1674                    Germany; Belgium; United States  ...  3.850000e+12
# 1843                  United States; Pakistan; Colombia  ...  3.000000e+11
# 2389                               Switzerland; Austria  ...  7.520000e+11
# 2489                                     China; Germany  ...  1.470000e+13
# 2915                            France; Pakistan; Nepal  ...  3.000000e+11
# 3068                                     China; Germany  ...  3.850000e+12
# 3238                               United States; India  ...  2.670000e+12
# 3291                                     Italy; Germany  ...  3.850000e+12
# 3293                                    Brazil; Germany  ...  3.850000e+12
# 3760                                            Germany  ...  3.850000e+12
# 3972                                     China; Germany  ...  3.850000e+12
# 4116                                            Germany  ...  3.850000e+12
# 4166                                            Germany  ...  3.850000e+12
# 4169                                            Germany  ...  3.850000e+12
# 4546                                      United States  ...  2.090000e+13
# 4667    Pakistan; Germany; Russia; India; United States  ...  3.850000e+12
# 4767                             Germany; United States  ...  2.090000e+13
# 5186                                    Brazil; Germany  ...  3.850000e+12
# 5260    Germany; Australia; United States; Saudi Arabia  ...  3.850000e+12
# 5798                                            Germany  ...  3.850000e+12
# 5821                                            Germany  ...  3.850000e+12
# 5826                                            Germany  ...  3.850000e+12
# 5892  Germany; Spain; Belgium; Saudi Arabia; Estonia...  ...           NaN
# 6398                                             Brazil  ...  1.450000e+12
# 6514                              Brazil; United States  ...  2.090000e+13
# 6730                                     Egypt; Germany  ...  3.850000e+12
# 6838                                     China; Germany  ...  3.850000e+12
# 7336                  Pakistan; France; Brazil; England  ...           NaN
# 8006                           Germany; Norway; Austria  ...  4.330000e+11
# 8615                                 Indonesia; Germany  ...  3.850000e+12
# 8851                                     China; Germany  ...  3.850000e+12
# 8858                                            Germany  ...  3.850000e+12
# 9375                           Saudi Arabia; Bangladesh  ...  3.740000e+11
# 9428                                            Hungary  ...  1.570000e+11
# 9470    India; United States; Ethiopia; Poland; Germany  ...  3.850000e+12
# 9494     India; United States; Syria; Ethiopia; Germany  ...  3.850000e+12
# 9551                                 Germany; Australia  ...  1.330000e+12
# 9756                                             Brazil  ...  1.450000e+12
# 9873                                     Egypt; Germany  ...  3.850000e+12
#
#      _merge                             Locations--all authors  \
# 252    both        Beijing, Beijing, China; Stuttgart, Germany
# 328    both  Berlin, Germany; Tirupati, Andhra Pradesh, Ind...
# 345    both  Jingzhou, Hubei, China; Beijing, Beijing, Chin...
# 574    both  Campinas, SP, Brazil; Recife, PE, Brazil; Bann...
# 909    both  Halle, Germany; Freiburg, Germany; Berlin, Ger...
# 912    both            Zurich, Switzerland; Basel, Switzerland
# 935    both                    Bonn, Germany; Giessen, Germany
# 936    both                    Bonn, Germany; Giessen, Germany
# 997    both            Innsbruck, Austria; Zurich, Switzerland
# 1255   both                 Potsdam, Germany; Dresden, Germany
# 1434   both  Bielefeld, Germany; Lincoln, New Zealand; Gott...
# 1674   both  Jena, Germany; Witzenhausen, Germany; Leuven, ...
# 1843   both  Los Angeles, CA, United States; Islamabad, Pun...
# 2389   both  Fribourg, Switzerland; Vienna, Austria; Wadens...
# 2489   both  Sanming, Fujian, China; Fuzhou, Fujian, China;...
# 2915   both  Illkirch Graffenstaden, France; Lahore, Punjab...
# 3068   both  Shanghai, Shaghai, China; Beijing, Beijing, Ch...
# 3238   both  Ardmore, OK, United States; Faridabad, Haryana...
# 3291   both  Faenza, RA, Italy; Bremen, Germany; Altavilla ...
# 3293   both  Piracicaba, SP, Brazil; Gottingen, Germany; Ca...
# 3760   both             Mittweida, Germany; Gottingen, Germany
# 3972   both  Baoding, Hebei, China; Kiel, Germany; Gatersle...
# 4116   both              Berlin, Germany; Grossbeeren, Germany
# 4166   both  Seeland, Germany; Berlin, Germany; Gottingen, ...
# 4169   both  Gatersleben, Germany; Berlin, Germany; Munich,...
# 4546   both  Geneva, NY, United States; Ithaca, NY, United ...
# 4667   both  Faisalabad, Punjab, Pakistan; Seeland, Germany...
# 4767   both  Kaiserslautern, Germany; Pullman, WA, United S...
# 5186   both  Vicosa, MG, Brazil; Fortaleza, Ceara, Brazil; ...
# 5260   both  Stuttgart, Germany; Parkville, Vic, Australia;...
# 5798   both              Frankfurt, Germany; Hannover, Germany
# 5821   both               Munich, Germany; Dusseldorf, Germany
# 5826   both  Seeland, Germany; Berlin, Germany; Bergen, Ger...
# 5892   both  Wurzburg, Germany; Moncada, Valencia, Spain; B...
# 6398   both      Mossoro, RN, Brazil; Fortaleza, Ceara, Brazil
# 6514   both  Pelotas, RS, Brazil; Fayetteville, AR, United ...
# 6730   both                 Cairo, Egypt; Gatersleben, Germany
# 6838   both        Beijing, Beijing, China; Stuttgart, Germany
# 7336   both  Sargodha, Punjab, Pakistan; Lahore, Punjab, Pa...
# 8006   both  Berlin, Germany; Jena, Germany; Bielefeld, Ger...
# 8615   both  Pontianak, West Kalimantan, Indonesia; Dusseld...
# 8851   both              Jingzhou, Hubei, China; Jena, Germany
# 8858   both  Halle, Germany; Leipzig, Germany; Neuherberg, ...
# 9375   both  Riyadh, Saudi Arabia; Chittagong, Bangladesh; ...
# 9428   both                Godollo, Hungary; Budapest, Hungary
# 9470   both  Mumbai, Maharashtra, India; Solan, Himachal Pr...
# 9494   both  Solan, Himachal Pradesh, India; Mumbai, Mahara...
# 9551   both  Stuttgart, Germany; Ludwigshafen, Germany; Urr...
# 9756   both  Bambui, MG, Brazil; Sete Lagoas, MG, Brazil; S...
# 9756  (-11.8543783, -55.51026020000001); (-19.464669...
# 9873  (30.0444196, 31.235711600000005); (51.8018485,...
#
#                          Corresponding author locations  \
# 252         Beijing, Beijing, China; Stuttgart, Germany
# 328    Berlin, Germany; Tirupati, Andhra Pradesh, India
# 345               Jingzhou, Hubei, China; Jena, Germany
# 574           Campinas, SP, Brazil; Bannu, KP, Pakistan
# 909                  Freiburg, Germany; Berlin, Germany
# 912             Basel, Switzerland; Zurich, Switzerland
# 935                     Bonn, Germany; Giessen, Germany
# 936                     Bonn, Germany; Giessen, Germany
# 997             Innsbruck, Austria; Zurich, Switzerland
# 1255                 Potsdam, Germany; Dresden, Germany
# 1434           Bielefeld, Germany; Lincoln, New Zealand
# 1674               Jena, Germany; Witzenhausen, Germany
# 1843  Los Angeles, CA, United States; Islamabad, Pun...
# 2389         Fribourg, Switzerland; Zurich, Switzerland
# 2489      Sanming, Fujian, China; Fuzhou, Fujian, China
# 2915    Kirtipur, Nepal; Illkirch Graffenstaden, France
# 3068  Shanghai, Shaghai, China; Beijing, Beijing, Ch...
# 3238  Ardmore, OK, United States; Faridabad, Haryana...
# 3291                 Faenza, RA, Italy; Bremen, Germany
# 3293         Piracicaba, SP, Brazil; Gottingen, Germany
# 3760             Mittweida, Germany; Gottingen, Germany
# 3972                Kiel, Germany; Gatersleben, Germany
# 4116              Berlin, Germany; Grossbeeren, Germany
# 4166  Seeland, Germany; Berlin, Germany; Gottingen, ...
# 4169  Gatersleben, Germany; Berlin, Germany; Gotting...
# 4546  Geneva, NY, United States; Ithaca, NY, United ...
# 4667     Faisalabad, Punjab, Pakistan; Seeland, Germany
# 4767  Kaiserslautern, Germany; Pullman, WA, United S...
# 5186  Vicosa, MG, Brazil; Fortaleza, Ceara, Brazil; ...
# 5260      Parkville, Vic, Australia; Stuttgart, Germany
# 5798              Frankfurt, Germany; Hannover, Germany
# 5821               Munich, Germany; Dusseldorf, Germany
# 5826                  Seeland, Germany; Berlin, Germany
# 5892          Wurzburg, Germany; Bristol, Avon, England
# 6398      Mossoro, RN, Brazil; Fortaleza, Ceara, Brazil
# 6514  Pelotas, RS, Brazil; Fayetteville, AR, United ...
# 6730                 Cairo, Egypt; Gatersleben, Germany
# 6838        Beijing, Beijing, China; Stuttgart, Germany
# 7336  Sargodha, Punjab, Pakistan; Nottingham, Leics,...
# 8006                   Berlin, Germany; Vienna, Austria
# 8615  Pontianak, West Kalimantan, Indonesia; Dusseld...
# 8851              Jingzhou, Hubei, China; Jena, Germany
# 8858                   Halle, Germany; Leipzig, Germany
# 9375       Riyadh, Saudi Arabia; Chittagong, Bangladesh
# 9428                Godollo, Hungary; Budapest, Hungary
# 9470  Mumbai, Maharashtra, India; Solan, Himachal Pr...
# 9494  Solan, Himachal Pradesh, India; Mumbai, Mahara...
# 9551         Stuttgart, Germany; Urrbrae, SA, Australia
# 9756        Bambui, MG, Brazil; Sete Lagoas, MG, Brazil
# 9873                     Cairo, Egypt; Seeland, Germany
#
#                  Corresponding author geocoords Number of authoring countries  \
# 6838                                 2
# 7336                                 2
# 8006                                 2
# 8615                                 2
# 8851                                 2
# 8858                                 1
# 9375                                 2
# 9428                                 1
# 9470                                 2
# 9494                                 2
# 9551                                 2
# 9756                                 1
# 9873                                 2
#
#                                             unique_NCBI map_props
# 252                                                  []  0.500000
# 328                                              [4513]  0.500000
# 345                                     [297313, 65672]  0.500000
# 574                                            [332119]  0.500000
# 909                             [1117, 102234, 1892263]  0.500000
# 912                                                  []  0.500000
# 935                                     [63186, 245170]  0.500000
# 936                                     [63186, 245170]  0.500000
# 997                                              [3702]  0.500000
# 1255                                      [3750, 23211]  0.500000
# 1434                                      [29875, 4577]  0.500000
# 1674  [89151, 693967, 30080, 33373, 337508, 7524, 46...  0.500000
# 1843    [258323, 174218, 78381, 4454, 2544934, 2544936]  0.500000
# 2389           [6306, 181124, 1428, 97005, 51655, 3701]  0.500000
# 2489                         [556, 45173, 65672, 36459]  0.500000
# 2915                                     [23513, 67938]  0.500000
# 3068                                                 []  0.333333
# 3238                                                 []  0.500000
# 3291                                  [331606, 1678924]  0.500000
# 3293                     [4719, 143451, 29760, 1858064]  0.500000
# 3760                                            [28641]  0.500000
# 3972                                             [4565]  0.500000
# 4116                                                 []  0.500000
# 4166                                             [4513]  0.333333
# 4169                                                 []  0.333333
# 4546                          [3714, 3712, 3715, 36774]  0.500000
# 4667                                     [4565, 147389]  0.500000
# 4767                                       [4100, 4932]  0.500000
# 5186                                                 []  0.333333
# 5260                                            [63459]  0.500000
# 5798                                       [3702, 3049]  0.500000
# 5821                                             [3702]  0.500000
# 5826                                 [3702, 4513, 3701]  0.500000
# 5892                                                 []  0.500000
# 6398                                                 []  0.500000
# 6514                                                 []  0.500000
# 6730                           [1436093, 2810020, 4577]  0.500000
# 6838                                             [4577]  0.500000
# 7336                                   [1423376, 51383]  0.500000
# 8006                                                 []  0.500000
# 8615                                           [201017]  0.500000
# 8851                                      [3708, 65672]  0.500000
# 8858                                                 []  0.500000
# 9375                                           [316889]  0.500000
# 9428                                            [38588]  0.500000
# 9470                                 [4136, 4210, 3745]  0.333333
# 9494  [40918, 228163, 212957, 212256, 3501, 58334, 6...  0.333333
# 9551                                      [4565, 27439]  0.500000
# 9756                                            [29709]  0.500000
# 9873                                             [4577]  0.500000
#
# [50 rows x 62 columns]

# %%
# need to do the german last name thing
new_last_names_diff = []

for i in list(no_authors_diff_df.index):
    old_last_name = no_authors_diff_df.loc[i]['Corresponding_author_last_name']
    author_full_name = no_authors_diff_df.loc[i]['Author Full Names']
    # if the old last name is one insertion away from something in the author full names, then consider it a match
    new_last_name = regex.findall("("+old_last_name+"){i<=1,d<=1}", author_full_name, overlapped=True)
    # if there are still no matches, ignore for now
    if len(new_last_name) == 0:
        pass    
    else:
        new_last_names_diff.append([i,new_last_name[0]])

# %%
# replace last names in old dataframe with new last names (which contain an extra letter)
for i in range(len(new_last_names_diff)):
    no_authors_diff_df.at[new_last_names_diff[i][0],'Corresponding_author_last_name'] = new_last_names_diff[i][1]

# %%
no_authors_diff_df["first and last names"]=[re.findall(no_authors_diff_df.loc[i]['Corresponding_author_last_name']+"+[^;]*", no_authors_diff_df.loc[i]['Author Full Names']) for i in no_authors_diff_df.index]

# %%
# this is the problem

# %%
# drop people with no first names at this point
diff_loc_out = diff_loc_out[diff_loc_out["first and last names"].map(len)==1]

# %%
diff_loc_out[0:20]
# Out:
#     index                                  Author Full Names  \
# 0      15  Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...
# 1      15  Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...
# 2      50  Bernard, Miriam S.; Strittmatter, Martina; Mur...
# 3      50  Bernard, Miriam S.; Strittmatter, Martina; Mur...
# 4     132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...
# 5     132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...
# 6     204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...
# 7     204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...
# 9     249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...
# 11    251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...
# 12    541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...
# 13    541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...
# 14    662  Sunesen, Ines; Rodriguez, Francisco; Tardivo K...
# 15    662  Sunesen, Ines; Rodriguez, Francisco; Tardivo K...
# 16    684  Schoenrock, Kathryn M.; O'Connor, Aisha M.; Ma...
# 17    684  Schoenrock, Kathryn M.; O'Connor, Aisha M.; Ma...
# 18    834  Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; N...
# 20    873  Bock, Clive H.; Oliver, Jonathan E.; Chen, Chu...
# 21    873  Bock, Clive H.; Oliver, Jonathan E.; Chen, Chu...
# 22   1197  Conran, John G.; Bannister, Jennifer M.; Kaufu...
#
#                                         Article Title  \
# 0   CharaciopsisBorzi belongs to the Eustigmatophy...
# 1   CharaciopsisBorzi belongs to the Eustigmatophy...
# 2   Diversity, biogeography and host specificity o...
# 3   Diversity, biogeography and host specificity o...
# 4   Why one species in New Zealand, Pugetia delica...
# 5   Why one species in New Zealand, Pugetia delica...
# 6   Species distinctions among closely related str...
# 7   Species distinctions among closely related str...
# 9   Morphology, ultrastructure and molecular phylo...
# 11  Morpho-molecular diversity and phylogeny of By...
# 12  Haemolytic activity and reactive oxygen specie...
# 13  Haemolytic activity and reactive oxygen specie...
# 14  Morphological and molecular characterization o...
# 15  Morphological and molecular characterization o...
# 16  Genetic diversity of a marine foundation speci...
# 17  Genetic diversity of a marine foundation speci...
# 18  Effects of nitrogen deficiency on the transcri...
# 20  Pecan Bacterial Leaf Scorch, Caused by Xylella...
# 21  Pecan Bacterial Leaf Scorch, Caused by Xylella...
# 22  Pterostoma neehoffii (cf. Zamiaceae): a new sp...
#
#                           Journal  impact factor (2020)  \
# 0   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 1   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 2   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 3   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 4   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 5   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 6   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 7   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 9   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 11  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 12  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 13  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 14  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 15  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 16  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 17  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 18  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 20          PLANT HEALTH PROGRESS                 0.940
# 21          PLANT HEALTH PROGRESS                 0.940
# 22  NEW ZEALAND JOURNAL OF BOTANY                 0.970
#
#                                       Author Keywords  \
# 0   Characiopsis; Eustigmataceae group; Eustigmato...
# 1   Characiopsis; Eustigmataceae group; Eustigmato...
# 2   5'COI; barcoding; biogeography; endophytes; ho...
# 3   5'COI; barcoding; biogeography; endophytes; ho...
# 4   DNA sequencing; endemic genera; large-subunit ...
# 5   DNA sequencing; endemic genera; large-subunit ...
# 6   Eustigmatophyceae; Eustigmatos; fatty acids; i...
# 7   Eustigmatophyceae; Eustigmatos; fatty acids; i...
# 9   Bysmatrum; cyst; dinoflagellate; eyespot; Peri...
# 11  benthic dinoflagellate; biogeography; Bysmatru...
# 12  Dinoflagellate; haemolytic agent; harmful alga...
# 13  Dinoflagellate; haemolytic agent; harmful alga...
# 14  Body scales morphology; cell morphology; Dinop...
# 15  Body scales morphology; cell morphology; Dinop...
# 16  Boreal; climate refugia; dispersal; kelp; micr...
# 17  Boreal; climate refugia; dispersal; kelp; micr...
# 18  Fatty acid; lipid metabolism; molecular regula...
# 20                                                NaN
# 21                                                NaN
# 22  Fossil cycad; Hindon Maar Complex; Miocene; Ot...
#
#                                         Keywords Plus  \
# 0   ALGAL CLASS; PHYLOGENY; ULTRASTRUCTURE; NOMENC...
# 1   ALGAL CLASS; PHYLOGENY; ULTRASTRUCTURE; NOMENC...
# 2   ALGA CAULERPA-TAXIFOLIA; NUCLEAR RIBOSOMAL DNA...
# 3   ALGA CAULERPA-TAXIFOLIA; NUCLEAR RIBOSOMAL DNA...
# 4   SUBUNIT RDNA; GIGARTINACEAE RHODOPHYTA; MAXIMU...
# 5   SUBUNIT RDNA; GIGARTINACEAE RHODOPHYTA; MAXIMU...
# 6   CHAIN ALKYL DIOLS; GREEN-ALGAE; SECONDARY STRU...
# 7   CHAIN ALKYL DIOLS; GREEN-ALGAE; SECONDARY STRU...
# 9   FRESH-WATER DINOFLAGELLATE; RDNA-BASED PHYLOGE...
# 11  TIDAL POOL DINOFLAGELLATE; SP. NOV. DINOPHYCEA...
# 12  DINOFLAGELLATE HETEROCAPSA-CIRCULARISQUAMA; RE...
# 13  DINOFLAGELLATE HETEROCAPSA-CIRCULARISQUAMA; RE...
# 14  DINOFLAGELLATE GENUS; HETEROCAPSA; IDENTIFICAT...
# 15  DINOFLAGELLATE GENUS; HETEROCAPSA; IDENTIFICAT...
# 16  KELP POSTELSIA-PALMAEFORMIS; LAMINARIA-HYPERBO...
# 17  KELP POSTELSIA-PALMAEFORMIS; LAMINARIA-HYPERBO...
# 18  LIPID PRODUCTION; LIGHT-INTENSITY; CHLAMYDOMON...
# 20                                                NaN
# 21                                                NaN
# 22  LANDSLIP HILL SILCRETE; MANUHERIKIA GROUP; SP-...
#
#                                              Abstract  \
# 0   Characiopsis, established by Borzi in 1895, is...
# 1   Characiopsis, established by Borzi in 1895, is...
# 2   Endophytic filamentous brown algae are known t...
# 3   Endophytic filamentous brown algae are known t...
# 4   Blade-forming red algae occur worldwide and, p...
# 5   Blade-forming red algae occur worldwide and, p...
# 6   There is an increasing interest in the Eustigm...
# 7   There is an increasing interest in the Eustigm...
# 9   The dinoflagellate order Peridiniales encompas...
# 11  The dinoflagellate genus Bysmatrum encompasses...
# 12  Based on haemolytic activity and reactive oxyg...
# 13  Based on haemolytic activity and reactive oxyg...
# 14  A new species of the marine dinophyte genusHet...
# 15  A new species of the marine dinophyte genusHet...
# 16  Worldwide, kelp populations are stressed by wa...
# 17  Worldwide, kelp populations are stressed by wa...
# 18  The soil algal strainParachlorella kessleriTY ...
# 20  Pecan bacterial leaf scorch (PBLS), caused by ...
# 21  Pecan bacterial leaf scorch (PBLS), caused by ...
# 22  A fossil cycad pinna fragment with dichotomisi...
#
#                                Addresses--all authors  \
# 0   [Amaral, Raquel; Santos, Lilia M. A.] Univ Coi...
# 1   [Amaral, Raquel; Santos, Lilia M. A.] Univ Coi...
# 2   [Bernard, Miriam S.; Heesch, Svenja; Leblanc, ...
# 3   [Bernard, Miriam S.; Heesch, Svenja; Leblanc, ...
# 4   [D'Archino, Roberta] Natl Inst Water & Atmosph...
# 5   [D'Archino, Roberta] Natl Inst Water & Atmosph...
# 6   [Kryvenda, Anastasiia; Rybalka, Nataliya; Frie...
# 7   [Kryvenda, Anastasiia; Rybalka, Nataliya; Frie...
# 9   [Luo, Zhaohe; Gu, Li; Gu, Haifeng] Minist Nat ...
# 11  [Luo, Zhaohe; Li, Xintian; Gu, Haifeng] SOA, I...
# 12  [Cho, Kichul] Natl Inst Environm Res, Geum Riv...
# 13  [Cho, Kichul] Natl Inst Environm Res, Geum Riv...
# 14  [Sunesen, Ines; Tardivo Kubis, Jonas A.; Aguia...
# 15  [Sunesen, Ines; Tardivo Kubis, Jonas A.; Aguia...
# 16  [Schoenrock, Kathryn M.; O'Connor, Aisha M.] N...
# 17  [Schoenrock, Kathryn M.; O'Connor, Aisha M.] N...
# 18  [Gao, Yifan; Feng, Jia; Lv, Junping; Liu, Qi; ...
# 20  [Bock, Clive H.; Chen, Chunxian; Hotchkiss, Mi...
# 21  [Bock, Clive H.; Chen, Chunxian; Hotchkiss, Mi...
# 22  [Conran, John G.] Univ Adelaide, Sch Biol Sci,...
#
#                                Nations--all authors  ...      GDP_2020 _merge  \
# 0                                 Portugal; Czechia  ...  2.450000e+11   both
# 1                                 Portugal; Czechia  ...  2.450000e+11   both
# 2                     France; Scotland; South Korea  ...  2.630000e+12   both
# 3                     France; Scotland; South Korea  ...  2.630000e+12   both
# 4                New Zealand; Taiwan; United States  ...           NaN   both
# 5                New Zealand; Taiwan; United States  ...           NaN   both
# 6                                           Germany  ...  3.850000e+12   both
# 7                                           Germany  ...  3.850000e+12   both
# 9                  China; France; Canada; Indonesia  ...  2.630000e+12   both
# 11  China; Malaysia; France; Belgium; United States  ...  2.630000e+12   both
# 12                               South Korea; Japan  ...           NaN   both
# 13                               South Korea; Japan  ...           NaN   both
# 14                        Argentina; Spain; Germany  ...  3.850000e+12   both
# 15                        Argentina; Spain; Germany  ...  3.850000e+12   both
# 16         Ireland; United States; France; Portugal  ...  2.090000e+13   both
# 17         Ireland; United States; France; Portugal  ...  2.090000e+13   both
# 18                             China; United States  ...  2.090000e+13   both
Galway, Galway, Ireland; Birmingham, AL, Unite...
# 17  Galway, Galway, Ireland; Birmingham, AL, Unite...
# 18   Taiyuan, Shanxi, China; Upton, NY, United States
# 20  Byron, GA, United States; Tifton, GA, United S...
# 21  Byron, GA, United States; Tifton, GA, United S...
# 22      Adelaide, SA, Australia; Dunedin, New Zealand
#
#              Corresponding author geocoords Number of authoring countries  \
# 0           (40.20331450000001, -8.4102573)                             2
# 1          (49.8209226, 18.262524300000006)                             2
# 2                   (48.703091, -4.0292009)                             3
# 3                    (48.726199, -3.985325)                             3
# 4         (-41.2923814, 174.77874630000005)                             3
# 5                 (25.1275997, 121.7391815)                             3
# 6            (49.79130439999999, 9.9533548)                             1
# 7            (51.54128040000001, 9.9158035)                             1
# 9            (47.87283400000001, -3.920734)                             4
# 11           (47.87283400000001, -3.920734)                             5
# 12  (32.78519960000001, 129.86664059999998)                             2
# 13                (33.4996213, 126.5311884)                             2
# 14        (-34.9204948, -57.95356570000001)                             3
# 15                  (53.5395845, 8.5809424)                             3
# 16                (33.5185892, -86.8103567)                             4
# 17          (53.27066800000001, -9.0567905)                             4
# 18                  (37.8705899, 112.55067)                             2
# 20        (31.450462899999994, -83.5084973)                             1
# 21        (32.653756099999995, -83.7596295)                             1
# 22               (-34.9284989, 138.6007456)                             2
#
#    Number of corresponding countries  \
# 0                                  2
# 1                                  2
# 2                                  1
# 3                                  1
# 4                                  2
# 5                                  2
# 6                                  1
# 7                                  1
# 9                                  2
# 11                                 2
# 12                                 2
# 13                                 2
# 14                                 2
# 15                                 2
# 16                                 2
# 17                                 2
# 18                                 2
# 20                                 1
# 21                                 1
# 22                                 2
#
#                                           unique_NCBI map_props
# 0   [425071, 2713033, 1431827, 5747, 44429, 271303...       0.5
# 1   [425071, 2713033, 1431827, 5747, 44429, 271303...       0.5
# 2   [90893, 64910, 64922, 64929, 309358, 172714, 6...       0.5
# 3   [90893, 64910, 64922, 64929, 309358, 172714, 6...       0.5
# 4          [217477, 1789642, 1789644, 1789643, 31430]       0.5
# 5          [217477, 1789642, 1789644, 1789643, 31430]       0.5
# 6                                [44427, 5747, 44431]       0.5
# 7                                [44427, 5747, 44431]       0.5
# 9   [54902, 2867, 66803, 991128, 2137288, 1691972,...       0.5
# 11           [2077185, 2077196, 990649, 990648, 2910]       0.5
# 12  [859642, 90936, 10190, 225107, 139025, 201731,...       0.5
# 13  [859642, 90936, 10190, 225107, 139025, 201731,...       0.5
# 14                                    [2650469, 2918]       0.5
# 15                                    [2650469, 2918]       0.5
# 16                                    [90893, 172714]       0.5
# 17                                    [90893, 172714]       0.5
# 18                            [686709, 1116978, 3074]       0.5
# 20                                             [2371]       0.5
# 21                                             [2371]       0.5
# 22                               [987446, 3298, 3297]       0.5
#
# [20 rows x 62 columns]

# %%
diff_loc_out["first and last names"] = [i[0].split(', ') for i in diff_loc_out["first and last names"]]

# %%
diff_loc_out["First name"] = [i[-1] for i in diff_loc_out["first and last names"]]

# %%
diff_loc_out["Last name"] = [i[0] for i in diff_loc_out["first and last names"]]

# %%
diff_loc_names = diff_loc_out.merge(names_dict, how='left', on='First name')

# %%
diff_loc_na = diff_loc_names[diff_loc_names['inferred_gender_y'].isna()].drop_duplicates(subset=['First name'])

# %%
diff_loc_na['Corresponding_auth_country'] = [i[-1] for i in diff_loc_na['Corresponding author locations'].str.split(',')]

# %%
# diff_loc_na[['First name','Last name','Corresponding_auth_country']].to_csv('diff_location.csv', index=False)

# %%
diff_loc_enriched = pd.read_csv('diff_location_enriched.csv')

# %%
diff_loc_na['inferred_gender'] = list(diff_loc_enriched['ga_gender'])

# %%
# for i in diff_loc_na.index:
#     diff_loc_names.at[i,'inferred_gender_y'] = diff_loc_na.at[i,'inferred_gender']

# %%
diff_loc_na[['index', 'First name', 'inferred_gender']]
# Out:
#        index    First name inferred_gender
# 3         50      Akira F.          female
# 8        249  Kenneth Neil            male
# 11       541      Daekyung            male
# 39      3174          Hang             NaN
# 40      3174   Komiljon Sh            male
# ...      ...           ...             ...
# 8503  288960        Junlae          female
# 8505  289045        Zhishu             NaN
# 8506  289045         Jinao          female
# 8507  289058          Suin          female
# 8511  289282      Hui-xing            male
#
# [803 rows x 3 columns]

# %% [markdown]
# # Merge back with original data

# %%
diff_loc_out = diff_loc_df.explode(['Corresponding author Addresses','Corresponding author geocoords'])
diff_loc_out['map_props'] /= diff_loc_out['map_props'].groupby(level=0).transform('count')

# %%
diff_loc_out['Corresponding_author_last_name'] = diff_loc_out['Corresponding author Addresses'].str.split(', ').str[0]

# %%
diff_loc_out["first and last names"]=[re.findall(diff_loc_out.iloc[i]['Corresponding_author_last_name']+"+[^;]*", diff_loc_out.iloc[i]['Author Full Names']) for i in range(len(diff_loc_out))]

# %%
diff_loc_out = diff_loc_out.reset_index()

# %%
# find entries that have no corresponding author name extracted
no_authors_diff = []

for i in diff_loc_out.index:
    if len(diff_loc_out.loc[i]['first and last names']) == 0:
        no_authors_diff.append(i)
        
no_authors_diff_df = diff_loc_out.loc[no_authors_diff]

# %%
# need to do the german last name thing
new_last_names_diff = []

for i in list(no_authors_diff_df.index):
    old_last_name = no_authors_diff_df.loc[i]['Corresponding_author_last_name']
    author_full_name = no_authors_diff_df.loc[i]['Author Full Names']
    # if the old last name is one insertion away from something in the author full names, then consider it a match
    new_last_name = regex.findall("("+old_last_name+"){i<=1,d<=1}", author_full_name, overlapped=True)
    # if there are still no matches, ignore for now
    if len(new_last_name) == 0:
        pass    
    else:
        new_last_names_diff.append([i,new_last_name[0]])

# %%
# replace last names in old dataframe with new last names (which contain an extra letter)
for i in range(len(new_last_names_diff)):
    no_authors_diff_df.at[new_last_names_diff[i][0],'Corresponding_author_last_name'] = new_last_names_diff[i][1]

# %%
no_authors_diff_df["first and last names"]=[re.findall(no_authors_diff_df.loc[i]['Corresponding_author_last_name']+"+[^;]*", no_authors_diff_df.loc[i]['Author Full Names']) for i in no_authors_diff_df.index]

# %%
mult_author_df = diff_loc_out[diff_loc_out["first and last names"].map(len) != 1]

# %%
mult_author_df['Corresponding_author_last_name'] = mult_author_df['Corresponding author Addresses'].str.findall(r'^[^,]*,..').str[0]
# Out:
# /tmp/ipykernel_447643/3790255992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mult_author_df['Corresponding_author_last_name'] = mult_author_df['Corresponding author Addresses'].str.findall(r'^[^,]*,..').str[0]

# %%
mult_author_df['Corresponding_author_last_name'] = mult_author_df['Corresponding_author_last_name'].str.strip()
# Out:
# /tmp/ipykernel_447643/4227390828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mult_author_df['Corresponding_author_last_name'] = mult_author_df['Corresponding_author_last_name'].str.strip()

# %%
# use previous cell to find first and last names of corresponding authors
author_matches = []

for i in mult_author_df.index:
    mylist = mult_author_df.loc[i]['first and last names']
    r = re.compile(str(mult_author_df.loc[i]['Corresponding_author_last_name'])+".*")
    newlist = list(filter(r.match, mylist))
    author_matches.append(newlist)
    
mult_author_df['first and last names'] = author_matches
# Out:
# /tmp/ipykernel_447643/1175752697.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mult_author_df['first and last names'] = author_matches

# %%
for i in mult_author_df.index:
    diff_loc_out.at[i,'first and last names'] = mult_author_df.at[i,'first and last names']

# %%
for i in diff_loc_out["first and last names"]:
    try:
        diff_loc_out.at[i,"first and last names"] = i[0].split(', ')
    except:
        pass

# %%
First_name = []

for i in diff_loc_out["first and last names"]:
    try:
        First_name.append(i[-1])
    except:
        First_name.append('None')
        
diff_loc_out["First name"] = First_name

# %%
Last_name = []

for i in diff_loc_out["first and last names"]:
    try:
        Last_name.append(i[0])
    except:
        Last_name.append('None')
        
diff_loc_out["Last name"] = Last_name

# %%
diff_loc_out[0:15][['Author Full Names', 'inferred_gender']]
# Out:
#                                      Author Full Names inferred_gender
# 15   Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...          female
# 15   Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...          female
# 50   Bernard, Miriam S.; Strittmatter, Martina; Mur...          female
# 50   Bernard, Miriam S.; Strittmatter, Martina; Mur...          female
# 132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...          female
# 132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...          female
# 204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...            male
# 204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...            male
# 249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...          female
# 249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...          female
# 251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...            male
# 251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...            male
# 541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...            male
# 541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...            male
# 662  Sunesen, Ines; Rodriguez, Francisco; Tardivo K...          female

# %%
merged_diff_loc = diff_loc_out.merge(diff_loc_na, how = 'inner', on = ['index', 'First name'])
# Out:
# /tmp/ipykernel_447643/2966709017.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'inferred_gender_y'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_diff_loc = diff_loc_out.merge(diff_loc_na, how = 'inner', on = ['index', 'First name'])

# %%
# strategy 2: make new dictionary

# %%
diff_loc_enriched = pd.read_csv('diff_location_enriched.csv')

# %%
one_loc_enriched = pd.read_csv('one_location_enriched.csv')

# %%
names_dict_diff = diff_loc_enriched[['First name', 'ga_gender']]

# %%
names_dict_diff = names_dict_diff.rename(columns = {'ga_gender': 'inferred_gender'})

# %%
names_dict_one = one_loc_enriched[['First name', 'ga_gender']]

# %%
names_dict_one = names_dict_one.rename(columns = {'ga_gender': 'inferred_gender'})

# %%
names_dict_final = pd.concat([names_dict, names_dict_diff, names_dict_one])

# %%
diff_loc_names_final = diff_loc_out.merge(names_dict_final, how='left', on='First name')

# %%
diff_loc_names_final[0:15]
# Out:
#     index                                  Author Full Names  \
# 0      15  Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...
# 1      15  Amaral, Raquel; Sevcikova, Tereza; Elias, Mare...
# 2      50  Bernard, Miriam S.; Strittmatter, Martina; Mur...
# 3      50  Bernard, Miriam S.; Strittmatter, Martina; Mur...
# 4     132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...
# 5     132  D'Archino, Roberta; Lin, Showe-Mei; Gabrielson...
# 6     204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...
# 7     204  Kryvenda, Anastasiia; Rybalka, Nataliya; Wolf,...
# 8     249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...
# 9     249  Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Eli...
# 10    251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...
# 11    251  Luo, Zhaohe; Lim, Zhen Fei; Mertens, Kenneth N...
# 12    541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...
# 13    541  Cho, Kichul; Kasaoka, Takuya; Ueno, Mikinori; ...
# 14    662  Sunesen, Ines; Rodriguez, Francisco; Tardivo K...
#
#                                         Article Title  \
# 0   CharaciopsisBorzi belongs to the Eustigmatophy...
# 1   CharaciopsisBorzi belongs to the Eustigmatophy...
# 2   Diversity, biogeography and host specificity o...
# 3   Diversity, biogeography and host specificity o...
# 4   Why one species in New Zealand, Pugetia delica...
# 5   Why one species in New Zealand, Pugetia delica...
# 6   Species distinctions among closely related str...
# 7   Species distinctions among closely related str...
# 8   Morphology, ultrastructure and molecular phylo...
# 9   Morphology, ultrastructure and molecular phylo...
# 10  Morpho-molecular diversity and phylogeny of By...
# 11  Morpho-molecular diversity and phylogeny of By...
# 12  Haemolytic activity and reactive oxygen specie...
# 13  Haemolytic activity and reactive oxygen specie...
# 14  Morphological and molecular characterization o...
#
#                           Journal  impact factor (2020)  \
# 0   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 1   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 2   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 3   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 4   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 5   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 6   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 7   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 8   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 9   EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 10  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 11  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 12  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 13  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 14  EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
#
#                                       Author Keywords  \
# 0   Characiopsis; Eustigmataceae group; Eustigmato...
# 1   Characiopsis; Eustigmataceae group; Eustigmato...
# 2   5'COI; barcoding; biogeography; endophytes; ho...
# 3   5'COI; barcoding; biogeography; endophytes; ho...
# 4   DNA sequencing; endemic genera; large-subunit ...
# 5   DNA sequencing; endemic genera; large-subunit ...
# 6   Eustigmatophyceae; Eustigmatos; fatty acids; i...
# 7   Eustigmatophyceae; Eustigmatos; fatty acids; i...
# 8   Bysmatrum; cyst; dinoflagellate; eyespot; Peri...
# 9   Bysmatrum; cyst; dinoflagellate; eyespot; Peri...
# 10  benthic dinoflagellate; biogeography; Bysmatru...
# 11  benthic dinoflagellate; biogeography; Bysmatru...
# 12  Dinoflagellate; haemolytic agent; harmful alga...
# 13  Dinoflagellate; haemolytic agent; harmful alga...
# 14  Body scales morphology; cell morphology; Dinop...
#
#                                         Keywords Plus  \
# 0   ALGAL CLASS; PHYLOGENY; ULTRASTRUCTURE; NOMENC...
# 1   ALGAL CLASS; PHYLOGENY; ULTRASTRUCTURE; NOMENC...
# 2   ALGA CAULERPA-TAXIFOLIA; NUCLEAR RIBOSOMAL DNA...
# 3   ALGA CAULERPA-TAXIFOLIA; NUCLEAR RIBOSOMAL DNA...
# 4   SUBUNIT RDNA; GIGARTINACEAE RHODOPHYTA; MAXIMU...
# 5   SUBUNIT RDNA; GIGARTINACEAE RHODOPHYTA; MAXIMU...
# 6   CHAIN ALKYL DIOLS; GREEN-ALGAE; SECONDARY STRU...
# 7   CHAIN ALKYL DIOLS; GREEN-ALGAE; SECONDARY STRU...
# 8   FRESH-WATER DINOFLAGELLATE; RDNA-BASED PHYLOGE...
# 9   FRESH-WATER DINOFLAGELLATE; RDNA-BASED PHYLOGE...
# 10  TIDAL POOL DINOFLAGELLATE; SP. NOV. DINOPHYCEA...
# 11  TIDAL POOL DINOFLAGELLATE; SP. NOV. DINOPHYCEA...
# 12  DINOFLAGELLATE HETEROCAPSA-CIRCULARISQUAMA; RE...
# 13  DINOFLAGELLATE HETEROCAPSA-CIRCULARISQUAMA; RE...
# 14  DINOFLAGELLATE GENUS; HETEROCAPSA; IDENTIFICAT...
#
#                                              Abstract  \
# 0   Characiopsis, established by Borzi in 1895, is...
# 1   Characiopsis, established by Borzi in 1895, is...
# 2   Endophytic filamentous brown algae are known t...
# 3   Endophytic filamentous brown algae are known t...
# 4   Blade-forming red algae occur worldwide and, p...
# 5   Blade-forming red algae occur worldwide and, p...
# 6   There is an increasing interest in the Eustigm...
# 7   There is an increasing interest in the Eustigm...
# 8   The dinoflagellate order Peridiniales encompas...
# 9   The dinoflagellate order Peridiniales encompas...
# 10  The dinoflagellate genus Bysmatrum encompasses...
# 11  The dinoflagellate genus Bysmatrum encompasses...
# 12  Based on haemolytic activity and reactive oxyg...
# 13  Based on haemolytic activity and reactive oxyg...
# 14  A new species of the marine dinophyte genusHet...
#
#                                Addresses--all authors  \
# 0   [Amaral, Raquel; Santos, Lilia M. A.] Univ Coi...
# 1   [Amaral, Raquel; Santos, Lilia M. A.] Univ Coi...
# 2   [Bernard, Miriam S.; Heesch, Svenja; Leblanc, ...
# 3   [Bernard, Miriam S.; Heesch, Svenja; Leblanc, ...
# 4   [D'Archino, Roberta] Natl Inst Water & Atmosph...
# 5   [D'Archino, Roberta] Natl Inst Water & Atmosph...
# 6   [Kryvenda, Anastasiia; Rybalka, Nataliya; Frie...
# 7   [Kryvenda, Anastasiia; Rybalka, Nataliya; Frie...
# 8   [Luo, Zhaohe; Gu, Li; Gu, Haifeng] Minist Nat ...
# 9   [Luo, Zhaohe; Gu, Li; Gu, Haifeng] Minist Nat ...
# 10  [Luo, Zhaohe; Li, Xintian; Gu, Haifeng] SOA, I...
# 11  [Luo, Zhaohe; Li, Xintian; Gu, Haifeng] SOA, I...
# 12  [Cho, Kichul] Natl Inst Environm Res, Geum Riv...
# 13  [Cho, Kichul] Natl Inst Environm Res, Geum Riv...
# 14  [Sunesen, Ines; Tardivo Kubis, Jonas A.; Aguia...
#
#                                Nations--all authors  ...  \
# 0                                 Portugal; Czechia  ...
# 1                                 Portugal; Czechia  ...
# 2                     France; Scotland; South Korea  ...
# 3                     France; Scotland; South Korea  ...
# 4                New Zealand; Taiwan; United States  ...
# 5                New Zealand; Taiwan; United States  ...
# 6                                           Germany  ...
# 7                                           Germany  ...
# 8                  China; France; Canada; Indonesia  ...
# 9                  China; France; Canada; Indonesia  ...
# 10  China; Malaysia; France; Belgium; United States  ...
# 11  China; Malaysia; France; Belgium; United States  ...
# 12                               South Korea; Japan  ...
# 13                               South Korea; Japan  ...
# 14                        Argentina; Spain; Germany  ...
#
#                                Geocoords--all authors  \
# 0   (40.20331450000001, -8.4102573); (49.8209226, ...
# 1   (40.20331450000001, -8.4102573); (49.8209226, ...
# 2   (37.41379999999999, 127.5183); (48.703091, -4....
# 3   (37.41379999999999, 127.5183); (48.703091, -4....
# 4   (-41.2923814, 174.77874630000005); (25.1275997...
# 5   (-41.2923814, 174.77874630000005); (25.1275997...
# 6   (49.79130439999999, 9.9533548); (51.5412804000...
# 7   (49.79130439999999, 9.9533548); (51.5412804000...
# 8   (-6.2250138, 106.9004472); (34.2658138, 108.95...
# 9   (-6.2250138, 106.9004472); (34.2658138, 108.95...
# 10  (30.627977, -96.3344068); (34.2658138, 108.954...
# 11  (30.627977, -96.3344068); (34.2658138, 108.954...
# 12  (32.78519960000001, 129.86664059999998); (33.4...
# 13  (32.78519960000001, 129.86664059999998); (33.4...
# 14  (-34.9204948, -57.95356570000001); (42.1861627...
#
#                        Corresponding author locations  \
# 0                 Coimbra, Portugal; Ostrava, Czechia
# 1                 Coimbra, Portugal; Ostrava, Czechia
# 2                     Roscoff, France; Santec, France
# 3                     Roscoff, France; Santec, France
# 4            Wellington, New Zealand; Keelung, Taiwan
# 5            Wellington, New Zealand; Keelung, Taiwan
# 6               Gottingen, Germany; Wurzburg, Germany
# 7               Gottingen, Germany; Wurzburg, Germany
# 8            Xian, Shaanxi, China; Concarneau, France
# 9            Xian, Shaanxi, China; Concarneau, France
# 10           Xian, Shaanxi, China; Concarneau, France
# 11           Xian, Shaanxi, China; Concarneau, France
# 12  Bunkyo Machi, Nagasaki, Japan; Cheju, Jeju Do,...
# 13  Bunkyo Machi, Nagasaki, Japan; Cheju, Jeju Do,...
# 14  La Plata, Buenos Aires, Argentina; Bremerhaven...
#
#              Corresponding author geocoords Number of authoring countries  \
# 0           (40.20331450000001, -8.4102573)                             2
# 1          (49.8209226, 18.262524300000006)                             2
# 2                   (48.703091, -4.0292009)                             3
# 3                    (48.726199, -3.985325)                             3
# 4         (-41.2923814, 174.77874630000005)                             3
# 5                 (25.1275997, 121.7391815)                             3
# 6            (49.79130439999999, 9.9533548)                             1
# 7            (51.54128040000001, 9.9158035)                             1
# 8                 (34.2658138, 108.9540936)                             4
# 9            (47.87283400000001, -3.920734)                             4
# 10                (34.2658138, 108.9540936)                             5
# 11           (47.87283400000001, -3.920734)                             5
# 12  (32.78519960000001, 129.86664059999998)                             2
# 13                (33.4996213, 126.5311884)                             2
# 14        (-34.9204948, -57.95356570000001)                             3
#
#    Number of corresponding countries  \
# 0                                  2
# 1                                  2
# 2                                  1
# 3                                  1
# 4                                  2
# 5                                  2
# 6                                  1
# 7                                  1
# 8                                  2
# 9                                  2
# 10                                 2
# 11                                 2
# 12                                 2
# 13                                 2
# 14                                 2
#
#                                           unique_NCBI map_props  \
# 0   [425071, 2713033, 1431827, 5747, 44429, 271303...       0.5
# 1   [425071, 2713033, 1431827, 5747, 44429, 271303...       0.5
# 2   [90893, 64910, 64922, 64929, 309358, 172714, 6...       0.5
# 3   [90893, 64910, 64922, 64929, 309358, 172714, 6...       0.5
# 4          [217477, 1789642, 1789644, 1789643, 31430]       0.5
# 5          [217477, 1789642, 1789644, 1789643, 31430]       0.5
# 6                                [44427, 5747, 44431]       0.5
# 7                                [44427, 5747, 44431]       0.5
# 8   [54902, 2867, 66803, 991128, 2137288, 1691972,...       0.5
# 9   [54902, 2867, 66803, 991128, 2137288, 1691972,...       0.5
# 10           [2077185, 2077196, 990649, 990648, 2910]       0.5
# 11           [2077185, 2077196, 990649, 990648, 2910]       0.5
# 12  [859642, 90936, 10190, 225107, 139025, 201731,...       0.5
# 13  [859642, 90936, 10190, 225107, 139025, 201731,...       0.5
# 14                                    [2650469, 2918]       0.5
#
#                 First name               Last name inferred_gender_y
# 0           Amaral, Raquel          Amaral, Raquel               NaN
# 1             Elias, Marek            Elias, Marek               NaN
# 2       Bernard, Miriam S.      Bernard, Miriam S.               NaN
# 3         Peters, Akira F.        Peters, Akira F.               NaN
# 4       D'Archino, Roberta      D'Archino, Roberta               NaN
# 5           Lin, Showe-Mei          Lin, Showe-Mei               NaN
# 6           Friedl, Thomas          Friedl, Thomas               NaN
# 7           Wolf, Matthias          Wolf, Matthias               NaN
# 8              Gu, Haifeng             Gu, Haifeng               NaN
# 9    Mertens, Kenneth Neil   Mertens, Kenneth Neil               NaN
# 10             Gu, Haifeng             Gu, Haifeng               NaN
# 11   Mertens, Kenneth Neil   Mertens, Kenneth Neil               NaN
# 12            Oda, Tatsuya            Oda, Tatsuya               NaN
# 13           Kim, Daekyung           Kim, Daekyung               NaN
# 14         Sar, Eugenia A.         Sar, Eugenia A.               NaN
#
# [15 rows x 65 columns]

# %%
diff_loc_out['First name'][0]
# Out:
# 'Amaral, Raquel'

# %%
# old merging

# %%
data = pd.read_csv('../ete3/Plt_sci_publications_geo_species_8.26.csv', low_memory=False)

# %%
data.loc[249]['Corresponding_author_last_name']
# Out:
# 'Gu'

# %%
data.loc[249]['Corresponding author Addresses']
# Out:
# 'Gu, HF (corresponding author), Minist Nat Resources, Inst Oceanog 3, Xiamen 361005, Peoples R China.; Mertens, KN (corresponding author), IFREMER, LER BO, Stn Biol Marine, Pl Croix,BP40537, F-29185 Concarneau, France.'

# %%
data.loc[249]['Author Full Names']
# Out:
# 'Luo, Zhaohe; Mertens, Kenneth Neil; Nezan, Elizabeth; Gu, Li; Pospelova, Vera; Thoha, Hikmah; Gu, Haifeng'

# %%
one_loc_names_merged = (one_loc_names.groupby(['index'])
    .agg({'inferred_gender_y': lambda x: x.tolist()}))

# %%
one_loc_names_merged.loc[0]['inferred_gender_y']
# Out:
# ['male', 'female']

# %%
diff_loc_names_merged = (diff_loc_names.groupby(['index'])
    .agg({'inferred_gender_y': lambda x: x.tolist()}))

# %%
diff_loc_names_merged
# Out:
#        inferred_gender_y
# index
# 15        [female, male]
# 50      [female, female]
# 132     [female, female]
# 204         [male, male]
# 249               [male]
# ...                  ...
# 289754          [female]
# 289763      [male, male]
# 290266      [male, male]
# 290469      [male, male]
# 291858            [male]
#
# [4481 rows x 1 columns]

# %%
for i in one_loc_names_merged.index:
    data.at[i,'inferred_gender'] = one_loc_names_merged.at[i,'inferred_gender_y']

# %%
for i in diff_loc_names_merged.index:
    data.at[i,'inferred_gender'] = diff_loc_names_merged.at[i,'inferred_gender_y']

# %%
# data.to_csv('data_full_gender.csv', index = False)

# %%
# data.to_pickle('data_full_gender.pkl')

# %%
data['inferred_gender'].loc[0]
# Out:
# ['male', 'female']

# %% [markdown]
# ### Subcase 3: Some authors have different locations. Drop these
# Some authors may correspond to more than one location and or/ multiple authors may correspond to one location

# %%
# get everything not in subcases 1 or 2
step1 = mult_authors_df[~mult_authors_df.isin(one_loc_df)].dropna(subset=['Author Full Names'])
mult_loc_df = step1[~step1.isin(diff_loc_df)].dropna(subset=['Author Full Names'])

# %%
# probably drop these (around 4k)
mult_loc_df
# Out:
#                                         Author Full Names  \
# 568     Pena, Viviana; Belanger, David; Gagnon, Patric...
# 694     Schwartz, Nicole; Dobretsov, Sergey; Rohde, Sv...
# 703     Shan, Tifeng; Pang, Shaojun; Wang, Xuemei; Li,...
# 1791    Acuna, Rafael; Fliesswasser, Stella; Ackermann...
# 1908    Boo, Ga Hun; Tu Van Nguyen; Kim, Jung Yeon; Le...
# ...                                                   ...
# 289741  Thioune, El-Hadji; Strickler, Susan; Gallagher...
# 289755  Cao, Qinghe; Li, Ang; Chen, Jinyang; Sun, Yu; ...
# 290047  Poudel, Bindu; Abdalla, Osama A.; Liu, Qingchu...
# 290051  Ramos-Gonzalez, Pedro Luis; da Costa-Rodrigues...
# 291099  Youssef, Sami; Mahmood, Ahmed; Cartereau, Manu...
#
#                                             Article Title  \
# 568     Lithothamnion (Hapalidiales, Rhodophyta) in th...
# 694     Comparison of antifouling properties of native...
# 703     Genetic analysis of a recently established Und...
# 1791    Phylogenetic relationships and generic re-arra...
# 1908    A revised classification of the Gelidiellaceae...
# ...                                                   ...
# 289741  Temperature Impacts the Response ofCoffea cane...
# 289755  Transcriptome Sequencing of the Sweet Potato P...
# 290047  Field distribution and disease incidence of to...
# 290051  First genome sequence of an isolate of hibiscu...
# 291099  New cytological, morphological, and chorologic...
#
#                               Journal  impact factor (2020)  \
# 568     EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 694     EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 703     EUROPEAN JOURNAL OF PHYCOLOGY                 0.874
# 1791                            TAXON                 0.980
# 1908                            TAXON                 0.980
# ...                               ...                   ...
# 289741         TROPICAL PLANT BIOLOGY                 1.512
# 289755         TROPICAL PLANT BIOLOGY                 1.512
# 290047       TROPICAL PLANT PATHOLOGY                 1.512
# 290051       TROPICAL PLANT PATHOLOGY                 1.512
# 291099      TURKISH JOURNAL OF BOTANY                 1.489
#
#                                           Author Keywords  \
# 568     Coralline red algae; cox1; DNA barcoding; dist...
# 694     Antifouling; chemical defence; invasive alga; ...
# 703     Genetic diversity; invasive seaweed; kelp; mic...
# 1791    Blumenbachia; Caiophora; morphology; Loasa; pl...
# 1908    Gelidiales; Gelidiella; Madagascar; multigene ...
# ...                                                   ...
# 289741  Coffee; Drought; Water deficit; Combined water...
# 289755  Ipomoea trifida; Transcriptome; RNA-seq; Droug...
# 290047  Disease incidence; Field distribution; Groundn...
# 290051  Betacarmovirus; Hibiscus rosa-sinensis; High-t...
# 291099  Taxonomy; cytology; karyology; Prospero autumn...
#
#                                             Keywords Plus  \
# 568     RHODOLITH BEDS CORALLINALES; NORTH-ATLANTIC; P...
# 694     ALGA FUCUS-VESICULOSUS; LARVAL SETTLEMENT; MAR...
# 703     BROWN ALGA; R-PACKAGE; INVASION; PHAEOPHYCEAE;...
# 1791    SUBFAM. LOASOIDEAE; DNA-SEQUENCES; CORNALES; P...
# 1908    ACEROSA FORSSKAL FELDMANN; MARINE-ALGAE; GELID...
# ...                                                   ...
# 289741  CLIMATE-CHANGE; DROUGHT TOLERANCE; COFFEA-CANE...
# 289755  GERM PLASM; SYNTHETIC HEXAPLOIDS; IMPROVEMENT;...
# 290047  GROUNDNUT-RINGSPOT-VIRUS; INFECTING TOMATO; WI...
# 290051  IDENTIFICATION; PURIFICATION; EXPRESSION; CARM...
# 291099  SCILLA-AUTUMNALIS L.; GENERIC DELIMITATION; HY...
#
#                                                  Abstract  \
# 568     Coralline red algae in the non-geniculate gene...
# 694     The invasiveness of algal species can be facil...
# 703     Undaria pinnatifida, a kelp species native to ...
# 1791    Loasaceae, a mostly American group, is one of ...
# 1908    The agarophyte family Gelidiellaceae currently...
# ...                                                   ...
# 289741  Climate change is expected to result in more f...
# 289755  Ipomoea trifida (H.B.K.) G. Don. is the closes...
# 290047  Tomato chlorotic spot tospovirus is a species ...
# 290051  For the first time, the near-complete genome s...
# 291099  Prospero seisumsianum (Ruldans & Zetterl.) Yil...
#
#                                    Addresses--all authors  \
# 568     [Pena, Viviana] Univ A Coruna, Fac Ciencias, B...
# 694     [Schwartz, Nicole; Rohde, Sven; Schupp, Peter ...
# 703     [Shan, Tifeng; Pang, Shaojun; Wang, Xuemei; Li...
# 1791    [Acuna, Rafael; Fliesswasser, Stella; Ackerman...
# 1908    [Boo, Ga Hun] Univ Calif Berkeley, Univ Herbar...
# ...                                                   ...
# 289741  [Thioune, El-Hadji; Gallagher, Thomas; Osborne...
# 289755  [Cao, Qinghe; Li, Ang; Chen, Jinyang; Tang, Ju...
# 290047  [Poudel, Bindu; Abdalla, Osama A.; Liu, Qingch...
# 290051  [Ramos-Gonzalez, Pedro Luis; da Costa-Rodrigue...
# 291099  [Youssef, Sami; Vela, Errol] Univ Montpellier,...
#
#                                      Nations--all authors  \
# 568     Spain; Canada; United States; France; Norway; ...
# 694                                         Germany; Oman
# 703                        China; Germany; England; Japan
# 1791                           Germany; Costa Rica; Chile
# 1908    United States; South Korea; Vietnam; France; S...
# ...                                                   ...
# 289741        Ireland; France; United States; Switzerland
# 289755                                              China
# 290047                               United States; Egypt
# 290051                                             Brazil
# 291099                                       France; Iraq
#
#                            Corresponding author Addresses  ...  \
# 568     [Pena, V (corresponding author), Univ A Coruna...  ...
# 694     [Schwartz, N (corresponding author), Carl von ...  ...
# 703     [Shan, TF,  Pang, SJ (corresponding author), C...  ...
# 1791    [Acuna, R,  Weigend, M (corresponding author),...  ...
# 1908    [Boo, GH (corresponding author), Univ Calif Be...  ...
# ...                                                   ...  ...
# 289741  [Osborne, B (corresponding author), Univ Coll ...  ...
# 289755  [Cao, QH (corresponding author), Minist Agr, K...  ...
# 290047  [Poudel, B,  Zhang, SA (corresponding author),...  ...
# 290051  [Ramos-Gonzalez, PL,  Freitas-Astua, J (corres...  ...
# 291099  [Youssef, S,  Vela, E (corresponding author), ...  ...
#
#        Per_capita_income_2020      GDP_2020 _merge  \
# 568              63027.679530  2.090000e+13   both
# 694              31117.757710  7.397139e+10   both
# 703              54844.545970  3.850000e+12   both
# 1791             41608.025350  2.450000e+11   both
# 1908                      NaN           NaN   both
# ...                       ...           ...    ...
# 289741           46991.182030  2.630000e+12   both
# 289755           17189.281790  1.470000e+13   both
# 290047           63027.679530  2.090000e+13   both
# 290051           14834.193700  1.450000e+12   both
# 291099            9954.345263  1.840000e+11   both
#
#                                    Locations--all authors  \
# 568     La Coruna, Galicia, Spain; St John, NF, Canada...
# 694                  Wilhelmshaven, Germany; Muscat, Oman
# 703     Qingdao, Shandong, China; Beijing, Beijing, Ch...
# 1791    Bonn, Germany; Koblenz, Germany; Berlin, Germa...
# 1908    Berkeley, CA, United States; Taejon, Chungnam,...
# ...                                                   ...
# 289741  Glasnevin Hill, Dublin, Ireland; Rouen, France...
# 289755    Xuzhou, Jiangsu, China; Tianjin, Tianjin, China
# 290047  Homestead, FL, United States; Yuma, AZ, United...
# 290051  Vila Mariana, SP, Brazil; Piracicaba, SP, Braz...
# 291099  Montpellier, France; Sumail Duhok, Iraq; Marse...
#
#                                    Geocoords--all authors  \
# 568     (30.2240897, -92.0198427); (35.91319960000001,...
# 694     (23.5880307, 58.38287170000001); (53.532340299...
# 703     (34.9755668, 138.3826773); (36.0662299, 120.38...
# 1791    (-33.4488897, -70.66926550000002); (50.3569429...
# 1908    (10.8230989, 106.6296638); (36.7871202, 127.12...
# ...                                                   ...
# 289741  (42.4439614, -76.5018807); (46.2043907, 6.1431...
# 289755   (34.2043999, 117.28577); (39.0850999, 117.19937)
# 290047  (25.4687224, -80.4775569); (26.7617322, -81.43...
# 290051  (-12.6718752, -39.1039317); (-22.7342864, -47....
# 291099  (36.8632107, 42.9884805); (43.296482, 5.36978)...
#
#                            Corresponding author locations  \
# 568     La Coruna, Galicia, Spain; Chapel Hill, NC, Un...
# 694                  Wilhelmshaven, Germany; Muscat, Oman
# 703             Qingdao, Shandong, China; Bremen, Germany
# 1791                 Bonn, Germany; San Pedro, Costa Rica
# 1908    Berkeley, CA, United States; Taejon, Chungnam,...
# ...                                                   ...
# 289741     Glasnevin Hill, Dublin, Ireland; Tours, France
# 289755    Xuzhou, Jiangsu, China; Tianjin, Tianjin, China
# 290047  Homestead, FL, United States; Yuma, AZ, United...
# 290051  Vila Mariana, SP, Brazil; Cruz Das Almas, BA, ...
# 291099            Montpellier, France; Sumail Duhok, Iraq
#
#                            Corresponding author geocoords  \
# 568     [(35.91319960000001, -79.05584449999998),  (43...
# 694     [(23.5880307, 58.38287170000001),  (53.5323402...
# 703     [(36.0662299, 120.38298999999999),  (53.079296...
# 1791    [(50.73743, 7.0982068),  (9.9301517, -84.05110...
# 1908    [(36.7871202, 127.1205669),  (37.8715226000000...
# ...                                                   ...
# 289741  [(47.394144, 0.68484),  (53.3742486, -6.268633...
# 289755  [(34.2043999, 117.28577),  (39.0850999, 117.19...
# 290047  [(25.4687224, -80.4775569),  (32.6926512, -114...
# 290051  [(-12.6718752, -39.1039317),  (-23.589702, -46...
# 291099  [(36.8632107, 42.9884805),  (43.610769, 3.8767...
#
#        Number of authoring countries Number of corresponding countries  \
# 568                              9.0                               2.0
# 694                              2.0                               2.0
# 703                              4.0                               2.0
# 1791                             3.0                               2.0
# 1908                             6.0                               2.0
# ...                              ...                               ...
# 289741                           4.0                               2.0
# 289755                           1.0                               1.0
# 290047                           2.0                               1.0
# 290051                           1.0                               1.0
# 291099                           2.0                               2.0
#
#                                               unique_NCBI
# 568                                 [48605, 48598, 48601]
# 694         [74468, 74090, 2856, 10212, 10205, 3015, 536]
# 703                                       [172714, 74381]
# 1791    [37831, 193479, 187910, 37822, 37823, 2570285,...
# 1908    [564942, 1819763, 2026934, 417196, 28866, 2026...
# ...                                                   ...
# 289741                                            [13442]
# 289755                                             [4120]
# 290047                                                 []
# 290051                                                 []
# 291099                                            [82038]
#
# [3943 rows x 60 columns]

# %%
data = data[~data.index.isin(mult_loc_df.index)]

# %%
# data.to_pickle('data_full_gender.pkl')
